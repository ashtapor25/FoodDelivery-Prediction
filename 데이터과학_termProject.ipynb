# %% [markdown]
# <div style="text-align:center;"><h1>데이터 과학 Term Project</h1></div><br><br>
# <div style="text-align:right;">
#         <ul style="list-style:none;">
#             <li>2012120162 신준수</li>
#             <li>2014120108 정하람</li>
#             <li>2015410075 임경섭</li>
#             <li>2016320206 김효정</li>
#             <li>2016320221 김민재</li>
#         </ul>
# </div>
#
# # 배달 주문량 예측
#
#
# ## Problem
#
#   최근에 요식업 창업이 증가하고 배달 어플리케이션이 생겨나면서 배달음식에 대한 수요가 크게 증가하고 있다. 그러나 포화된 시장 속에서 개별적인 경쟁력을 갖추지 못해 폐업하는 비율도 상당하다. 이에 요식업에서 굉장히 중요한 이슈 중 하나인 '효율적인 재고 관리'를 위해 ‘배달 주문량을 예측’해보고자 한다. 날씨 데이터에만 의존했던 기존의 판매량 예측 모델과는 달리 다양한 특성들을 고려하여 보다 효과적인 모델을 설계해보고자 한다.
#
# ## Expected Result
#
#   정해진 feature들을 이용해 당일 배달 주문량을 적절한 오차 범위 내로 예측할  수 있는 모델을 구축해내는 것이 프로젝트의 최종 목표이다.
# 적절한 feature 선정(축소)을 위해 우선 heatmap과 PCA를 활용할 예정이고 그 외에도 여러 모델을 활용해 분석을 마친 뒤 최종 예측을 위해서는 Neural Network모델을 활용하여 학습시키고자 한다.
# 여기서 구축해낸 모델을 통해 자영업자들은 효율적인 재고관리라는 이점을 얻을 수 있고 배달앱의 수수료로 인해 배달앱과의 제휴를 꺼려하는 자영업자 및 소상공인들에게 제휴를 장려하도록 하여 배달 요식업계의 상생을 기대할 수 있다. 특히 배달 주문량의 데이터가 서울시에서만 기록되어 있는데 이 모델을 지방 업계에도 적용하여 적절한 평가를 진행하고 지역별 자영업 불균형을 해소하는 효과를 기대할 수 있다.

# %% [markdown]
# ## 1. Data Load

# %% [markdown]
# 1.target data:
#
# 배달음식 주문량(skt 빅데이터 허브)
#
# 2.features:
#
# 날씨 요인: 풍속, 강수량, 습도, 기온, 미세먼지(기상청)
#
# 경제 요인1: 기준금리(한국은행)
#
# 경제 요인2: 시가총액, 코스피지수, 체감 물가상승률(한국 거래소)
#
# 시간적 요인: 요일, 주말, 평일, 공휴일, 명절

# %% [markdown]
# ## 1.1 Preprocessing

# %% [markdown]
# ### 배달음식 주문량
#
# -> 날짜별로 주문량 합산

# %% [markdown]
# ### 주식데이터
#
# -> 휴일의 nan값 :
#
# 앞, 뒤 데이터의 평균 값을 넣는 방법과 앞, 뒤 데이터로 nan 값을 채우는 방법 두 가지 선택지가 있었다.
#
# 앞, 뒤 데이터로 nan 값을 채우는 것이 더 성능이 높게 나왔기에 이 방법을 선택하였고, 이는 주말의 이슈가 주식시장에 선행되어 반영되거나 장이 열린 후에 반영되는 경향으로 설명되는 것으로 보였다.
#
# (토요일엔 금요일 데이터로, 일요일엔 월요일 데이터로)
#
#
# ### 날씨 데이터
#
# -> 강수량이나 적설량의 경우 관측되는 일수가 현저히 적고, 강수량과 적설량이 관측되지 않았기에 nan값으로 둔 것으로 보여 nan값을 0으로 채웠다.
#
# ### 데이터 통합
#
# -> 전처리를 수행한 후에 날짜를 기준으로 모든 데이터를 통합하여 하나의 데이터 프레임으로 만들었다.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import robust_scale
from sklearn.linear_model import LinearRegression
from sklearn.metrics import explained_variance_score, mean_squared_error
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import explained_variance_score, mean_squared_error
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import mean_squared_log_error
from sklearn.preprocessing import normalize

# %%
data = pd.read_csv('raw_data2.csv', engine='python')
data = data.set_index('일자')
data_index = pd.to_datetime(data.index, infer_datetime_format = True)
data = data.reindex(data_index)

# %%
data
# Out:
#              통화건수  한국은행 기준금리   지점  평균기온(°C)  최저기온(°C)  최고기온(°C)  일강수량(mm)  \
# 일자
# 2013-12-01  62631       2.50  108       4.5       1.4       8.6       0.0
# 2013-12-02  35513       2.50  108       3.9       0.1       6.6       0.0
# 2013-12-03  38600       2.50  108       6.7       4.5       9.9       0.0
# 2013-12-04  40319       2.50  108       5.5       2.1       9.6       0.0
# 2013-12-05  42425       2.50  108       5.5       2.1       9.0       0.0
# 2013-12-06  50767       2.50  108       3.0      -0.7       7.0       0.0
# 2013-12-07  64412       2.50  108       6.2       3.8      11.0       0.1
# 2013-12-08  64725       2.50  108       4.2       2.5       6.5       0.0
# 2013-12-09  42083       2.50  108       3.8       1.9       5.2      14.0
# 2013-12-10  41425       2.50  108       0.3      -2.2       3.5       0.0
# 2013-12-11  45384       2.50  108      -1.7      -4.3       0.2       2.6
# 2013-12-12  48321       2.50  108      -3.2      -6.3       0.3       4.1
# 2013-12-13  57583       2.50  108      -6.8      -8.9      -4.3       0.0
# 2013-12-14  76072       2.50  108      -4.9      -8.5      -1.4       1.1
# 2013-12-15  68239       2.50  108      -4.4      -8.0       0.7       0.0
# 2013-12-16  39126       2.50  108      -3.6      -7.3       0.5       0.0
# 2013-12-17  41842       2.50  108      -0.3      -5.5       4.7       0.0
# 2013-12-18  42277       2.50  108       2.2      -0.9       6.5       0.8
# 2013-12-19  45495       2.50  108      -3.5      -6.5      -0.9       0.3
# 2013-12-20  52533       2.50  108      -4.0      -8.1      -0.1       0.0
# 2013-12-21  66611       2.50  108      -3.1      -6.3       0.9       0.0
# 2013-12-22  64178       2.50  108      -2.1      -6.8       3.1       0.0
# 2013-12-23  40710       2.50  108      -1.1      -3.7       2.3       0.0
# 2013-12-24  75330       2.50  108      -1.6      -5.9       4.0       0.0
# 2013-12-25  70276       2.50  108      -0.5      -4.4       3.7       0.0
# 2013-12-26  40634       2.50  108      -0.5      -4.0       2.7       1.6
# 2013-12-27  49839       2.50  108      -6.8      -9.3      -3.7       0.0
# 2013-12-28  63718       2.50  108      -6.5      -9.8      -2.7       0.0
# 2013-12-29  63911       2.50  108      -2.9      -8.0       1.6       0.1
# 2013-12-30  42781       2.50  108       2.2      -1.9       6.3       0.0
# ...           ...        ...  ...       ...       ...       ...       ...
# 2019-03-02  39115       1.75  108       7.8       1.3      14.7       0.0
# 2019-03-03  36724       1.75  108       9.4       2.5      16.1       0.0
# 2019-03-04  28736       1.75  108       9.9       5.0      16.3       0.0
# 2019-03-05  28100       1.75  108       8.4       5.6      12.9       0.0
# 2019-03-06  28867       1.75  108       8.4       5.7      12.4       0.0
# 2019-03-07  29549       1.75  108       7.0       3.1      12.7       0.0
# 2019-03-08  36050       1.75  108       6.1       0.6      13.4       0.0
# 2019-03-09  41518       1.75  108       7.2      -0.4      14.9       0.0
# 2019-03-10  38821       1.75  108      10.1       6.7      15.3       0.0
# 2019-03-11  25721       1.75  108       6.6       3.5      10.0       0.0
# 2019-03-12  28247       1.75  108       3.9      -0.3       7.9       0.0
# 2019-03-13  29390       1.75  108       3.5      -0.4       8.5       0.0
# 2019-03-14  30039       1.75  108       5.0      -1.7      10.0       0.0
# 2019-03-15  39792       1.75  108       5.5       1.6      11.3       3.5
# 2019-03-16  42350       1.75  108       4.3       0.2       9.2       0.0
# 2019-03-17  38389       1.75  108       6.3       2.6      12.4       0.0
# 2019-03-18  24716       1.75  108       7.1       1.4      14.4       0.0
# 2019-03-19  26227       1.75  108      10.0       3.4      16.7       0.0
# 2019-03-20  31805       1.75  108      10.3       7.1      14.6      16.5
# 2019-03-21  29779       1.75  108       7.1       1.9      11.1       3.3
# 2019-03-22  36939       1.75  108       3.3      -0.7       8.3       0.0
# 2019-03-23  43061       1.75  108       3.3      -0.4       8.2       1.7
# 2019-03-24  38615       1.75  108       4.3      -0.8       9.7       0.0
# 2019-03-25  25152       1.75  108       7.3       2.9      11.5       0.0
# 2019-03-26  28349       1.75  108      11.4       7.4      17.6       0.0
# 2019-03-27  27798       1.75  108      11.6       8.9      16.2       0.0
# 2019-03-28  28470       1.75  108       9.4       5.6      14.6       0.0
# 2019-03-29  34783       1.75  108       9.2       5.5      15.1       0.0
# 2019-03-30  42589       1.75  108       5.2       3.5       8.4       1.8
# 2019-03-31  38192       1.75  108       4.4       2.6       8.4       0.0
#
#             최대 순간 풍속(m/s)  평균 풍속(m/s)  평균 상대습도(%)  1시간 최다일사량(MJ/m2)  \
# 일자
# 2013-12-01            6.9         2.1        66.9              1.57
# 2013-12-02            5.2         1.4        64.3              0.53
# 2013-12-03            7.7         1.6        62.6              1.29
# 2013-12-04            6.2         1.8        72.8              1.28
# 2013-12-05            6.9         2.4        73.4              0.87
# 2013-12-06            7.2         2.7        42.6              1.63
# 2013-12-07            8.2         1.9        60.8              1.44
# 2013-12-08            6.3         2.8        75.3              0.40
# 2013-12-09           10.2         3.1        83.1              0.11
# 2013-12-10           10.4         3.2        56.1              1.56
# 2013-12-11           13.2         3.9        64.1              1.38
# 2013-12-12           11.0         2.7        69.9              0.92
# 2013-12-13            8.5         2.4        47.5              1.65
# 2013-12-14            6.6         1.5        65.4              1.19
# 2013-12-15            6.1         1.9        48.1              1.63
# 2013-12-16            5.9         1.8        52.6              0.94
# 2013-12-17            4.9         1.5        52.4              1.47
# 2013-12-18            8.0         2.4        65.1              1.45
# 2013-12-19           11.0         4.0        60.6              1.22
# 2013-12-20           10.1         2.6        56.3              1.41
# 2013-12-21            7.1         1.8        56.4              1.42
# 2013-12-22            5.7         1.9        57.5              1.50
# 2013-12-23            7.0         2.2        57.1              1.55
# 2013-12-24            5.4         1.7        58.0              1.47
# 2013-12-25            5.8         1.8        60.4              1.38
# 2013-12-26            9.9         2.6        67.8              0.65
# 2013-12-27            9.7         3.4        49.5              1.55
# 2013-12-28            9.7         2.5        44.1              1.63
# 2013-12-29            8.2         2.1        59.8              1.52
# 2013-12-30           12.2         2.9        55.4              1.23
# ...                   ...         ...         ...               ...
# 2019-03-02            5.4         1.1        37.6              2.17
# 2019-03-03            6.4         1.5        36.4              2.55
# 2019-03-04            7.6         1.9        46.1              2.30
# 2019-03-05            7.3         2.0        66.3              1.81
# 2019-03-06            7.2         2.0        55.0              1.61
# 2019-03-07            8.9         2.2        51.1              2.45
# 2019-03-08            8.0         1.9        39.4              2.71
# 2019-03-09            6.3         1.3        31.8              1.91
# 2019-03-10            5.8         1.2        26.4              1.62
# 2019-03-11            7.5         1.8        61.0              1.51
# 2019-03-12           11.0         2.7        55.1              1.16
# 2019-03-13           14.9         3.3        38.5              2.80
# 2019-03-14            7.3         1.9        45.3              2.34
# 2019-03-15            9.8         1.6        72.8              1.58
# 2019-03-16            8.1         1.8        69.9              2.39
# 2019-03-17            9.0         2.0        55.4              2.87
# 2019-03-18            7.8         1.4        43.8              2.55
# 2019-03-19            6.7         1.4        52.0              2.30
# 2019-03-20            7.9         1.4        79.0              0.78
# 2019-03-21           11.3         2.9        77.4              1.33
# 2019-03-22            9.5         2.8        40.9              3.05
# 2019-03-23           12.8         2.4        46.9              2.05
# 2019-03-24           10.6         2.3        45.4              2.98
# 2019-03-25            8.8         2.0        56.1              1.05
# 2019-03-26            8.9         2.0        51.1              2.96
# 2019-03-27           12.0         3.0        66.4              2.08
# 2019-03-28            7.9         2.6        49.9              2.79
# 2019-03-29            7.9         2.1        33.1              3.01
# 2019-03-30           13.0         2.9        72.0              1.34
# 2019-03-31           10.0         3.2        46.0              2.02
#
#             일 최심신적설(cm)  KOSPI지수  KOSDAQ지수
# 일자
# 2013-12-01          0.0  2030.78    512.69
# 2013-12-02          0.0  2030.78    512.69
# 2013-12-03          0.0  2009.36    508.16
# 2013-12-04          0.0  1986.80    506.28
# 2013-12-05          0.0  1984.77    506.32
# 2013-12-06          0.0  1980.41    506.32
# 2013-12-07          0.0  1980.41    506.32
# 2013-12-08          0.0  1980.41    506.32
# 2013-12-09          0.0  2000.38    502.23
# 2013-12-10          0.0  1993.45    497.72
# 2013-12-11          3.3  1977.97    494.78
# 2013-12-12          4.4  1967.93    495.64
# 2013-12-13          0.0  1962.91    494.36
# 2013-12-14          0.8  1962.91    494.36
# 2013-12-15          0.0  1962.91    494.36
# 2013-12-16          0.0  1961.15    488.19
# 2013-12-17          0.0  1965.74    486.15
# 2013-12-18          1.9  1974.63    485.65
# 2013-12-19          0.9  1975.65    484.17
# 2013-12-20          0.0  1983.35    488.41
# 2013-12-21          0.0  1983.35    488.41
# 2013-12-22          0.0  1983.35    488.41
# 2013-12-23          0.0  1996.89    489.63
# 2013-12-24          0.0  2001.59    491.08
# 2013-12-25          0.0  2001.59    491.08
# 2013-12-26          1.7  1999.30    488.87
# 2013-12-27          0.0  2002.28    496.77
# 2013-12-28          0.0  2002.28    496.77
# 2013-12-29          0.1  2002.28    496.77
# 2013-12-30          0.0  2011.34    499.99
# ...                 ...      ...       ...
# 2019-03-02          0.0  2195.44    731.25
# 2019-03-03          0.0  2190.66    748.07
# 2019-03-04          0.0  2190.66    748.07
# 2019-03-05          0.0  2179.23    747.95
# 2019-03-06          0.0  2175.60    746.70
# 2019-03-07          0.0  2165.79    736.83
# 2019-03-08          0.0  2137.44    735.97
# 2019-03-09          0.0  2137.44    735.97
# 2019-03-10          0.0  2137.44    735.97
# 2019-03-11          0.0  2138.10    739.09
# 2019-03-12          0.0  2157.18    754.76
# 2019-03-13          0.0  2148.41    754.89
# 2019-03-14          0.0  2155.68    755.42
# 2019-03-15          0.0  2176.11    748.36
# 2019-03-16          0.0  2176.11    748.36
# 2019-03-17          0.0  2179.49    753.13
# 2019-03-18          0.0  2179.49    753.13
# 2019-03-19          0.0  2177.62    748.91
# 2019-03-20          0.0  2177.10    749.76
# 2019-03-21          0.0  2184.88    743.52
# 2019-03-22          0.0  2186.95    743.97
# 2019-03-23          0.0  2186.95    743.97
# 2019-03-24          0.0  2144.86    727.21
# 2019-03-25          0.0  2144.86    727.21
# 2019-03-26          0.0  2148.80    736.81
# 2019-03-27          0.0  2145.62    728.45
# 2019-03-28          0.0  2128.10    719.72
# 2019-03-29          0.0  2140.67    729.31
# 2019-03-30          0.0  2140.67    729.31
# 2019-03-31          0.0  2140.67    729.31
#
# [1947 rows x 14 columns]

# %% [markdown]
# ## 2. Feature Selection / Engineering

# %% [markdown]
# ### 2.1 Heatmap
#
# Feature가 과도하게 많아지면 데이터 또한 많이 필요해지고 overfitting의 위험이 커지는 등의 차원의 저주가 발생할 수 있다.
#
# 이를 방지하고 모델의 Feature중에서 데이터의 특성을 가장 잘 나타내는 주요 필드를 선택하기 위해 Heatmap을 사용했다.
#
# Heatmap의 결과를 보고 독립변수인 주문량(통화건수)과 연관성이 낮은 4가지 feature('지점', '최저기온(°C)', '최고기온(°C)', '최대 순간 풍속(m/s)')를 제거했다.

# %%
# 사용가능한 시스템의 TTF 폰트 목록
import matplotlib.font_manager as font_manager

font_list = font_manager.findSystemFonts(fontpaths=None, fontext='ttf')

print('사용가능한 TTF 폰트 개수:', len(font_list))
font_list # 목록에서 처음 10 개만 보기
# Out:
# 사용가능한 TTF 폰트 개수: 293
# ['C:\\Windows\\Fonts\\HANBatangExtBB.ttf',
#  'C:\\WINDOWS\\Fonts\\framd.ttf',
#  'C:\\Windows\\Fonts\\HANBatang.ttf',
#  'C:\\WINDOWS\\Fonts\\segoepr.ttf',
#  'C:\\Windows\\Fonts\\malgunbd.ttf',
#  'C:\\WINDOWS\\Fonts\\Candarai.ttf',
#  'C:\\WINDOWS\\Fonts\\consolai.ttf',
#  'C:\\WINDOWS\\Fonts\\MH.TTF',
#  'C:\\WINDOWS\\Fonts\\LeelUIsl.ttf',
#  'C:\\Windows\\Fonts\\NanumBarunpenR.ttf',
#  'C:\\Windows\\Fonts\\msyi.ttf',
#  'C:\\WINDOWS\\Fonts\\courbd.ttf',
#  'C:\\Windows\\Fonts\\courbd.ttf',
#  'C:\\Windows\\Fonts\\georgiab.ttf',
#  'C:\\WINDOWS\\Fonts\\seguihis.ttf',
#  'C:\\WINDOWS\\Fonts\\seguibl.ttf',
#  'C:\\Windows\\Fonts\\corbelz.ttf',
#  'C:\\WINDOWS\\Fonts\\seguisb.ttf',
#  'C:\\WINDOWS\\Fonts\\seguisym.ttf',
#  'C:\\Windows\\Fonts\\corbelb.ttf',
#  'C:\\WINDOWS\\Fonts\\msyi.ttf',
#  'C:\\WINDOWS\\Fonts\\Gabriola.ttf',
#  'C:\\Windows\\Fonts\\segoeui.ttf',
#  'C:\\Windows\\Fonts\\seguibl.ttf',
#  'C:\\WINDOWS\\Fonts\\holomdl2.ttf',
#  'C:\\Windows\\Fonts\\gadugi.ttf',
#  'C:\\WINDOWS\\Fonts\\calibrili.ttf',
#  'C:\\Windows\\Fonts\\Candaraz.ttf',
#  'C:\\WINDOWS\\Fonts\\segoeuisl.ttf',
#  'C:\\Windows\\Fonts\\calibriz.ttf',
#  'C:\\WINDOWS\\Fonts\\timesi.ttf',
#  'C:\\WINDOWS\\Fonts\\verdanaz.ttf',
#  'C:\\WINDOWS\\Fonts\\MN.TTF',
#  'C:\\WINDOWS\\Fonts\\seguibli.ttf',
#  'C:\\Windows\\Fonts\\impact.ttf',
#  'C:\\WINDOWS\\Fonts\\malgunsl.ttf',
#  'C:\\Windows\\Fonts\\couri.ttf',
#  'C:\\WINDOWS\\Fonts\\wingding.ttf',
#  'C:\\WINDOWS\\Fonts\\calibriz.ttf',
#  'C:\\WINDOWS\\Fonts\\HANBatangB.ttf',
#  'C:\\Windows\\Fonts\\simsunb.ttf',
#  'C:\\Windows\\Fonts\\seguibli.ttf',
#  'C:\\WINDOWS\\Fonts\\segoeprb.ttf',
#  'C:\\WINDOWS\\Fonts\\ariblk.ttf',
#  'C:\\WINDOWS\\Fonts\\segoesc.ttf',
#  'C:\\Windows\\Fonts\\l_10646.ttf',
#  'C:\\Windows\\Fonts\\pala.ttf',
#  'C:\\Windows\\Fonts\\tahoma.ttf',
#  'C:\\Windows\\Fonts\\MM.TTF',
#  'C:\\WINDOWS\\Fonts\\consola.ttf',
#  'C:\\WINDOWS\\Fonts\\MG.TTF',
#  'C:\\Windows\\Fonts\\seguili.ttf',
#  'C:\\Windows\\Fonts\\corbel.ttf',
#  'C:\\WINDOWS\\Fonts\\palabi.ttf',
#  'C:\\Windows\\Fonts\\webdings.ttf',
#  'C:\\WINDOWS\\Fonts\\cambriai.ttf',
#  'C:\\WINDOWS\\Fonts\\Candaraz.ttf',
#  'C:\\Windows\\Fonts\\mmrtextb.ttf',
#  'C:\\WINDOWS\\Fonts\\constan.ttf',
#  'C:\\Windows\\Fonts\\calibrib.ttf',
#  'C:\\WINDOWS\\Fonts\\himalaya.ttf',
#  'C:\\Windows\\Fonts\\ebrima.ttf',
#  'C:\\WINDOWS\\Fonts\\corbel.ttf',
#  'C:\\Windows\\Fonts\\palab.ttf',
#  'C:\\Windows\\Fonts\\calibril.ttf',
#  'C:\\Windows\\Fonts\\malgunsl.ttf',
#  'C:\\Windows\\Fonts\\LeelaUIb.ttf',
#  'C:\\Windows\\Fonts\\mmrtext.ttf',
#  'C:\\Windows\\Fonts\\NanumBrush.ttf',
#  'C:\\WINDOWS\\Fonts\\trebucit.ttf',
#  'C:\\WINDOWS\\Fonts\\HANDotumExt.ttf',
#  'C:\\Windows\\Fonts\\segmdl2.ttf',
#  'C:\\WINDOWS\\Fonts\\HANBatangExt.ttf',
#  'C:\\Windows\\Fonts\\cour.ttf',
#  'C:\\Windows\\Fonts\\comicz.ttf',
#  'C:\\WINDOWS\\Fonts\\corbelz.ttf',
#  'C:\\Windows\\Fonts\\MT.TTF',
#  'C:\\Windows\\Fonts\\taile.ttf',
#  'C:\\Windows\\Fonts\\verdanaz.ttf',
#  'C:\\Windows\\Fonts\\palabi.ttf',
#  'C:\\Windows\\Fonts\\cambriab.ttf',
#  'C:\\Windows\\Fonts\\phagspa.ttf',
#  'C:\\Windows\\Fonts\\phagspab.ttf',
#  'C:\\WINDOWS\\Fonts\\segoeuil.ttf',
#  'C:\\WINDOWS\\Fonts\\HYHWPEQ.TTF',
#  'C:\\Windows\\Fonts\\times.ttf',
#  'C:\\WINDOWS\\Fonts\\segoeuii.ttf',
#  'C:\\Windows\\Fonts\\MP.TTF',
#  'C:\\Windows\\Fonts\\segoeprb.ttf',
#  'C:\\Windows\\Fonts\\timesi.ttf',
#  'C:\\Windows\\Fonts\\framdit.ttf',
#  'C:\\WINDOWS\\Fonts\\JUMJA.TTF',
#  'C:\\Windows\\Fonts\\himalaya.ttf',
#  'C:\\Windows\\Fonts\\ebrimabd.ttf',
#  'C:\\Windows\\Fonts\\ZWAdobeF.TTF',
#  'C:\\WINDOWS\\Fonts\\palab.ttf',
#  'C:\\Windows\\Fonts\\segoepr.ttf',
#  'C:\\WINDOWS\\Fonts\\ntailub.ttf',
#  'C:\\WINDOWS\\Fonts\\impact.ttf',
#  'C:\\WINDOWS\\Fonts\\taileb.ttf',
#  'C:\\Windows\\Fonts\\timesbi.ttf',
#  'C:\\WINDOWS\\Fonts\\mvboli.ttf',
#  'C:\\Windows\\Fonts\\seguihis.ttf',
#  'C:\\WINDOWS\\Fonts\\NirmalaS.ttf',
#  'C:\\WINDOWS\\Fonts\\corbelb.ttf',
#  'C:\\WINDOWS\\Fonts\\seguisbi.ttf',
#  'C:\\Windows\\Fonts\\calibrili.ttf',
#  'C:\\WINDOWS\\Fonts\\arialbd.ttf',
#  'C:\\Windows\\Fonts\\timesbd.ttf',
#  'C:\\Windows\\Fonts\\Gabriola.ttf',
#  'C:\\WINDOWS\\Fonts\\l_10646.ttf',
#  'C:\\WINDOWS\\Fonts\\trebucbd.ttf',
#  'C:\\Windows\\Fonts\\comicbd.ttf',
#  'C:\\Windows\\Fonts\\Candarai.ttf',
#  'C:\\WINDOWS\\Fonts\\symbol.ttf',
#  'C:\\WINDOWS\\Fonts\\verdana.ttf',
#  'C:\\Windows\\Fonts\\comici.ttf',
#  'C:\\Windows\\Fonts\\courbi.ttf',
#  'C:\\WINDOWS\\Fonts\\MB.TTF',
#  'C:\\Windows\\Fonts\\constanz.ttf',
#  'C:\\Windows\\Fonts\\seguisb.ttf',
#  'C:\\Windows\\Fonts\\trebucbd.ttf',
#  'C:\\Windows\\Fonts\\MG.TTF',
#  'C:\\WINDOWS\\Fonts\\constani.ttf',
#  'C:\\WINDOWS\\Fonts\\HANDotumB.ttf',
#  'C:\\WINDOWS\\Fonts\\segoeuib.ttf',
#  'C:\\WINDOWS\\Fonts\\timesbd.ttf',
#  'C:\\Windows\\Fonts\\HANDotumB.ttf',
#  'C:\\WINDOWS\\Fonts\\consolab.ttf',
#  'C:\\Windows\\Fonts\\constani.ttf',
#  'C:\\Windows\\Fonts\\segoesc.ttf',
#  'C:\\Windows\\Fonts\\Inkfree.ttf',
#  'C:\\WINDOWS\\Fonts\\monbaiti.ttf',
#  'C:\\Windows\\Fonts\\MB.TTF',
#  'C:\\WINDOWS\\Fonts\\comicbd.ttf',
#  'C:\\WINDOWS\\Fonts\\georgiab.ttf',
#  'C:\\Windows\\Fonts\\comic.ttf',
#  'C:\\WINDOWS\\Fonts\\webdings.ttf',
#  'C:\\WINDOWS\\Fonts\\lucon.ttf',
#  'C:\\Windows\\Fonts\\JUMJA.TTF',
#  'C:\\Windows\\Fonts\\calibri.ttf',
#  'C:\\Windows\\Fonts\\malgun.ttf',
#  'C:\\Windows\\Fonts\\MN.TTF',
#  'C:\\WINDOWS\\Fonts\\NanumBarunpenR.ttf',
#  'C:\\WINDOWS\\Fonts\\seguiemj.ttf',
#  'C:\\Windows\\Fonts\\seguiemj.ttf',
#  'C:\\WINDOWS\\Fonts\\comic.ttf',
#  'C:\\Windows\\Fonts\\symbol.ttf',
#  'C:\\Windows\\Fonts\\trebuc.ttf',
#  'C:\\Windows\\Fonts\\NanumBarunpenB.ttf',
#  'C:\\WINDOWS\\Fonts\\corbeli.ttf',
#  'C:\\Windows\\Fonts\\NanumPen.ttf',
#  'C:\\Windows\\Fonts\\MJ.TTF',
#  'C:\\Windows\\Fonts\\ntailu.ttf',
#  'C:\\Windows\\Fonts\\verdanab.ttf',
#  'C:\\WINDOWS\\Fonts\\ntailu.ttf',
#  'C:\\WINDOWS\\Fonts\\tahoma.ttf',
#  'C:\\Windows\\Fonts\\trebucbi.ttf',
#  'C:\\WINDOWS\\Fonts\\taile.ttf',
#  'C:\\WINDOWS\\Fonts\\segoeui.ttf',
#  'C:\\Windows\\Fonts\\Candarab.ttf',
#  'C:\\WINDOWS\\Fonts\\teamviewer14.otf',
#  'C:\\WINDOWS\\Fonts\\gadugi.ttf',
#  'C:\\Windows\\Fonts\\georgiai.ttf',
#  'C:\\WINDOWS\\Fonts\\calibril.ttf',
#  'C:\\WINDOWS\\Fonts\\calibrib.ttf',
#  'C:\\WINDOWS\\Fonts\\times.ttf',
#  'C:\\Windows\\Fonts\\ntailub.ttf',
#  'C:\\Windows\\Fonts\\seguisbi.ttf',
#  'C:\\WINDOWS\\Fonts\\ebrimabd.ttf',
#  'C:\\WINDOWS\\Fonts\\micross.ttf',
#  'C:\\WINDOWS\\Fonts\\malgunbd.ttf',
#  'C:\\Windows\\Fonts\\lucon.ttf',
#  'C:\\WINDOWS\\Fonts\\mmrtextb.ttf',
#  'C:\\Windows\\Fonts\\HANDotum.ttf',
#  'C:\\WINDOWS\\Fonts\\phagspab.ttf',
#  'C:\\WINDOWS\\Fonts\\simsunb.ttf',
#  'C:\\Windows\\Fonts\\tahomabd.ttf',
#  'C:\\WINDOWS\\Fonts\\calibrii.ttf',
#  'C:\\WINDOWS\\Fonts\\NanumPen.ttf',
#  'C:\\Windows\\Fonts\\arialbd.ttf',
#  'C:\\WINDOWS\\Fonts\\MK.TTF',
#  'C:\\Windows\\Fonts\\gadugib.ttf',
#  'C:\\Windows\\Fonts\\seguisym.ttf',
#  'C:\\WINDOWS\\Fonts\\segoeuiz.ttf',
#  'C:\\WINDOWS\\Fonts\\tahomabd.ttf',
#  'C:\\WINDOWS\\Fonts\\trebucbi.ttf',
#  'C:\\WINDOWS\\Fonts\\marlett.ttf',
#  'C:\\WINDOWS\\Fonts\\courbi.ttf',
#  'C:\\WINDOWS\\Fonts\\HANBatang.ttf',
#  'C:\\WINDOWS\\Fonts\\cambriaz.ttf',
#  'C:\\WINDOWS\\Fonts\\timesbi.ttf',
#  'C:\\WINDOWS\\Fonts\\Candara.ttf',
#  'C:\\WINDOWS\\Fonts\\comicz.ttf',
#  'C:\\Windows\\Fonts\\Nirmala.ttf',
#  'C:\\WINDOWS\\Fonts\\couri.ttf',
#  'C:\\Windows\\Fonts\\consola.ttf',
#  'C:\\Windows\\Fonts\\HANBatangB.ttf',
#  'C:\\WINDOWS\\Fonts\\georgia.ttf',
#  'C:\\Windows\\Fonts\\calibrii.ttf',
#  'C:\\WINDOWS\\Fonts\\verdanab.ttf',
#  'C:\\WINDOWS\\Fonts\\palai.ttf',
#  'C:\\Windows\\Fonts\\micross.ttf',
#  'C:\\WINDOWS\\Fonts\\javatext.ttf',
#  'C:\\Windows\\Fonts\\mvboli.ttf',
#  'C:\\Windows\\Fonts\\georgiaz.ttf',
#  'C:\\Windows\\Fonts\\segoeuii.ttf',
#  'C:\\WINDOWS\\Fonts\\HANBatangExtBB.ttf',
#  'C:\\Windows\\Fonts\\segoeuisl.ttf',
#  'C:\\WINDOWS\\Fonts\\arialbi.ttf',
#  'C:\\Windows\\Fonts\\cambriaz.ttf',
#  'C:\\WINDOWS\\Fonts\\NanumBrush.ttf',
#  'C:\\WINDOWS\\Fonts\\ebrima.ttf',
#  'C:\\Windows\\Fonts\\segoescb.ttf',
#  'C:\\Windows\\Fonts\\HYHWPEQ.TTF',
#  'C:\\Windows\\Fonts\\corbeli.ttf',
#  'C:\\Windows\\Fonts\\sylfaen.ttf',
#  'C:\\Windows\\Fonts\\taileb.ttf',
#  'C:\\WINDOWS\\Fonts\\cour.ttf',
#  'C:\\WINDOWS\\Fonts\\comici.ttf',
#  'C:\\Windows\\Fonts\\holomdl2.ttf',
#  'C:\\Windows\\Fonts\\monbaiti.ttf',
#  'C:\\Windows\\Fonts\\NirmalaB.ttf',
#  'C:\\WINDOWS\\Fonts\\malgun.ttf',
#  'C:\\WINDOWS\\Fonts\\trebuc.ttf',
#  'C:\\Windows\\Fonts\\ariblk.ttf',
#  'C:\\WINDOWS\\Fonts\\ZWAdobeF.TTF',
#  'C:\\WINDOWS\\Fonts\\seguisli.ttf',
#  'C:\\Windows\\Fonts\\bahnschrift.ttf',
#  'C:\\Windows\\Fonts\\cambriai.ttf',
#  'C:\\Windows\\Fonts\\constan.ttf',
#  'C:\\WINDOWS\\Fonts\\ariali.ttf',
#  'C:\\Windows\\Fonts\\arial.ttf',
#  'C:\\WINDOWS\\Fonts\\HANBatangExtB.ttf',
#  'C:\\Windows\\Fonts\\palai.ttf',
#  'C:\\WINDOWS\\Fonts\\consolaz.ttf',
#  'C:\\WINDOWS\\Fonts\\NirmalaB.ttf',
#  'C:\\WINDOWS\\Fonts\\sylfaen.ttf',
#  'C:\\Windows\\Fonts\\consolai.ttf',
#  'C:\\Windows\\Fonts\\georgia.ttf',
#  'C:\\Windows\\Fonts\\NirmalaS.ttf',
#  'C:\\WINDOWS\\Fonts\\arial.ttf',
#  'C:\\WINDOWS\\Fonts\\MT.TTF',
#  'C:\\Windows\\Fonts\\LeelUIsl.ttf',
#  'C:\\WINDOWS\\Fonts\\calibri.ttf',
#  'C:\\WINDOWS\\Fonts\\gadugib.ttf',
#  'C:\\WINDOWS\\Fonts\\pala.ttf',
#  'C:\\WINDOWS\\Fonts\\LeelawUI.ttf',
#  'C:\\Windows\\Fonts\\HANBatangExt.ttf',
#  'C:\\WINDOWS\\Fonts\\bahnschrift.ttf',
#  'C:\\WINDOWS\\Fonts\\segoescb.ttf',
#  'C:\\Windows\\Fonts\\MK.TTF',
#  'C:\\Windows\\Fonts\\ariali.ttf',
#  'C:\\WINDOWS\\Fonts\\seguili.ttf',
#  'C:\\WINDOWS\\Fonts\\MM.TTF',
#  'C:\\Windows\\Fonts\\segoeuil.ttf',
#  'C:\\Windows\\Fonts\\seguisli.ttf',
#  'C:\\WINDOWS\\Fonts\\georgiai.ttf',
#  'C:\\Windows\\Fonts\\consolab.ttf',
#  'C:\\Windows\\Fonts\\verdanai.ttf',
#  'C:\\Windows\\Fonts\\wingding.ttf',
#  'C:\\Windows\\Fonts\\segoeuib.ttf',
#  'C:\\Windows\\Fonts\\teamviewer14.otf',
#  'C:\\WINDOWS\\Fonts\\constanz.ttf',
#  'C:\\Windows\\Fonts\\MH.TTF',
#  'C:\\WINDOWS\\Fonts\\Candarab.ttf',
#  'C:\\WINDOWS\\Fonts\\constanb.ttf',
#  'C:\\WINDOWS\\Fonts\\segmdl2.ttf',
#  'C:\\WINDOWS\\Fonts\\georgiaz.ttf',
#  'C:\\WINDOWS\\Fonts\\framdit.ttf',
#  'C:\\Windows\\Fonts\\Candara.ttf',
#  'C:\\Windows\\Fonts\\constanb.ttf',
#  'C:\\Windows\\Fonts\\javatext.ttf',
#  'C:\\Windows\\Fonts\\consolaz.ttf',
#  'C:\\WINDOWS\\Fonts\\LeelaUIb.ttf',
#  'C:\\WINDOWS\\Fonts\\Nirmala.ttf',
#  'C:\\Windows\\Fonts\\arialbi.ttf',
#  'C:\\WINDOWS\\Fonts\\verdanai.ttf',
#  'C:\\WINDOWS\\Fonts\\HANDotum.ttf',
#  'C:\\WINDOWS\\Fonts\\MJ.TTF',
#  'C:\\WINDOWS\\Fonts\\Inkfree.ttf',
#  'C:\\Windows\\Fonts\\HANDotumExt.ttf',
#  'C:\\WINDOWS\\Fonts\\MP.TTF',
#  'C:\\Windows\\Fonts\\LeelawUI.ttf',
#  'C:\\Windows\\Fonts\\framd.ttf',
#  'C:\\Windows\\Fonts\\verdana.ttf',
#  'C:\\Windows\\Fonts\\segoeuiz.ttf',
#  'C:\\Windows\\Fonts\\trebucit.ttf',
#  'C:\\WINDOWS\\Fonts\\mmrtext.ttf',
#  'C:\\Windows\\Fonts\\HANBatangExtB.ttf',
#  'C:\\WINDOWS\\Fonts\\phagspa.ttf',
#  'C:\\WINDOWS\\Fonts\\cambriab.ttf',
#  'C:\\WINDOWS\\Fonts\\NanumBarunpenB.ttf']

# %%
#font_path = 'C:/Windows/Fonts/EBS훈민정음R.ttf'
#fontprop = fm.FontProperties(fname=font_path, size=18)

#plt.ylabel('가격', fontproperties=fontprop)
#plt.title('가격변동 추이', fontproperties=fontprop)

def Heatmap():
    fontprop = font_manager.FontProperties(fname="NanumBarunpenB.ttf", size=24)
    font_fname =  'C:\\WINDOWS\\Fonts\\NanumBarunpenB.ttf'
    font_family = font_manager.FontProperties(fname=font_fname).get_name()

    plt.rcParams["font.family"] = font_family
    #plt.rcParams["font.family"] = 'NanumBarunpenB'
    plt.rcParams["font.size"] = 5
    #plt.rcParams["figure.figsize"] = (15,4)

    # 그래프의 크기 지정
    plt.figure(figsize=(8, 8))

    # Heatmap 설정
    sns.heatmap(data.corr(), linewidths=0.1, vmax=0.5, cmap=plt.cm.gist_heat,
            linecolor='white', annot=True)

    # 렌더링
    #plt.legend()
    #plt.legend(prop={'family':'NanumBarunpenB', 'size':20})
    #plt.ylabel(data.columns,fontproperties=fontprop)
    plt.show()

# %%
Heatmap()
# Out:
# c:\program files\python\python36\lib\site-packages\matplotlib\font_manager.py:1241: UserWarning: findfont: Font family ['NanumBarunpen'] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#연관성 적은 4개 제거
data = data.drop(columns = ['지점', '최저기온(°C)', '최고기온(°C)', '최대 순간 풍속(m/s)'])

# %% [markdown]
# ## 2.2: Add Weekday Data
#
#  주말인지 평일인지, 무슨 요일인지에 따라 배달 주문량에 변화가 있을 것으로 판단해 one_hot_encoding 방식을 사용해 Feature에 Weekday Data를 추가했다.

# %%
day_of_week = pd.Series([x.weekday() for x in data.index], index = data.index)
day_dummies = pd.get_dummies(day_of_week, prefix='weekday', drop_first=False)
data = pd.concat([data, day_dummies], axis=1)

# %% [markdown]
# ## 2.3: Add Previous week Data
#
# ### Base Feature
#
# 기존의 주문량 예측 모델, 예측 성공률 50%, 평균 주문량 등 무엇을 Base Model로 정하는 것이 가장 좋을지 협의했다.
#
# 해당날짜의 1~7일 전의 평균 주문량과 일주일 전 같은요일 주문량을 Base Model로 정했다.
#
# 선택하게 된 이유는 연속적 성질을 지니고 있는 날씨, 경제적, 시간적 요인을 잘 설명해줄 수 있으며 직관적이기 때문이다.

# %%
target_data = data['통화건수']

prev_week_avg_list = [np.nan] * 7
prev_week = [np.nan] * 7
for idx in range(7, len(target_data)):
    avg = target_data.iloc[idx-7:idx].mean()
    prev_week_avg_list.append(avg)
    prev_week.append(target_data.iloc[idx-7])
    
prev_week_avg = pd.Series(prev_week_avg_list, index = data.index)
prev_week = pd.Series(prev_week, index=data.index)
prev_week_avg_fill = prev_week_avg.fillna(method='bfill')

data = pd.concat([data, pd.DataFrame(prev_week_avg_fill, columns=['prev_week_avg'])], axis=1)

# %% [markdown]
# ## 2.4: Add Holiday Data
#
# 공휴일과 명절에는 배달 주문량이 평소와는 다르게 관측될 것이라고 판단해 one_hot_encoding 방식을 사용해 Feature에 공휴일, 명절 Data를 추가했다.

# %%
data = data.loc['2014-01-01':]
years = pd.read_csv('공휴일/'+str(2014)+' 공휴일.csv', engine='python',error_bad_lines=False, sep=',')
for year in range(2015, 2020):
    indiv_year = pd.read_csv('공휴일/'+str(year)+' 공휴일.csv', engine='python',error_bad_lines=False, sep=',')
    years = pd.concat([years, indiv_year])

years = years.set_index('holyday_array')
years = years.drop('Unnamed: 0', axis=1)

holiday = pd.Series([1 for x in years.index], index = years.index)
myungjul = pd.Series([(1 if x in ['설날', '추석'] else 0) for x in years['holyday_name_array']], index=years.index)

holiday_index = pd.to_datetime(holiday.index, infer_datetime_format = True)
holiday = pd.Series(data = holiday, index = holiday_index)
myungjul = pd.Series(data = myungjul, index = holiday_index)

holiday = holiday[holiday_index.duplicated()==False].reindex(data.index, fill_value=0)
myungjul = myungjul[holiday_index.duplicated()==False].reindex(data.index, fill_value=0)

data = pd.concat([data, pd.DataFrame(holiday, columns=['holiday']), pd.DataFrame(myungjul, columns=['myungjul'])], axis=1)

# %%
data['2019-02-01':]
# Out:
#              통화건수  한국은행 기준금리  평균기온(°C)  일강수량(mm)  평균 풍속(m/s)  평균 상대습도(%)  \
# 일자
# 2019-02-01  39948       1.75      -2.1       0.3         1.7        47.6
# 2019-02-02  37267       1.75       1.4       0.0         1.0        60.0
# 2019-02-03  34189       1.75       3.3      16.0         1.7        92.9
# 2019-02-04  20200       1.75      -0.6       0.0         2.1        40.4
# 2019-02-05  13188       1.75       2.8       0.0         1.0        37.1
# 2019-02-06  29025       1.75       5.1       0.0         1.3        54.9
# 2019-02-07  28385       1.75      -2.1       0.5         3.5        45.5
# 2019-02-08  35320       1.75      -6.1       0.0         2.3        31.5
# 2019-02-09  41716       1.75      -5.4       0.0         2.7        30.0
# 2019-02-10  40979       1.75      -5.0       0.0         1.7        31.3
# 2019-02-11  28984       1.75      -3.0       0.0         2.3        34.9
# 2019-02-12  30391       1.75      -0.6       0.0         1.9        35.5
# 2019-02-13  32641       1.75      -2.1       0.0         2.4        26.6
# 2019-02-14  33729       1.75      -0.5       0.0         1.4        24.3
# 2019-02-15  44047       1.75      -0.8       2.2         1.9        72.8
# 2019-02-16  43597       1.75      -2.7       0.2         2.6        59.0
# 2019-02-17  40108       1.75      -1.8       0.0         1.9        47.4
# 2019-02-18  28155       1.75       0.9       0.0         1.3        43.5
# 2019-02-19  32211       1.75       1.4       4.6         1.4        80.8
# 2019-02-20  32679       1.75       1.7       0.0         2.1        67.8
# 2019-02-21  35201       1.75       2.4       0.0         1.5        59.4
# 2019-02-22  38416       1.75       4.0       0.0         1.5        56.1
# 2019-02-23  41485       1.75       6.8       0.0         1.1        41.0
# 2019-02-24  39924       1.75       6.3       0.0         1.8        45.0
# 2019-02-25  29855       1.75       4.7       0.0         2.3        55.8
# 2019-02-26  31159       1.75       5.2       0.0         1.6        32.8
# 2019-02-27  32927       1.75       7.8       0.0         1.6        31.3
# 2019-02-28  38470       1.75       6.6       0.0         2.0        39.5
# 2019-03-01  40672       1.75       6.6       0.0         2.1        42.3
# 2019-03-02  39115       1.75       7.8       0.0         1.1        37.6
# 2019-03-03  36724       1.75       9.4       0.0         1.5        36.4
# 2019-03-04  28736       1.75       9.9       0.0         1.9        46.1
# 2019-03-05  28100       1.75       8.4       0.0         2.0        66.3
# 2019-03-06  28867       1.75       8.4       0.0         2.0        55.0
# 2019-03-07  29549       1.75       7.0       0.0         2.2        51.1
# 2019-03-08  36050       1.75       6.1       0.0         1.9        39.4
# 2019-03-09  41518       1.75       7.2       0.0         1.3        31.8
# 2019-03-10  38821       1.75      10.1       0.0         1.2        26.4
# 2019-03-11  25721       1.75       6.6       0.0         1.8        61.0
# 2019-03-12  28247       1.75       3.9       0.0         2.7        55.1
# 2019-03-13  29390       1.75       3.5       0.0         3.3        38.5
# 2019-03-14  30039       1.75       5.0       0.0         1.9        45.3
# 2019-03-15  39792       1.75       5.5       3.5         1.6        72.8
# 2019-03-16  42350       1.75       4.3       0.0         1.8        69.9
# 2019-03-17  38389       1.75       6.3       0.0         2.0        55.4
# 2019-03-18  24716       1.75       7.1       0.0         1.4        43.8
# 2019-03-19  26227       1.75      10.0       0.0         1.4        52.0
# 2019-03-20  31805       1.75      10.3      16.5         1.4        79.0
# 2019-03-21  29779       1.75       7.1       3.3         2.9        77.4
# 2019-03-22  36939       1.75       3.3       0.0         2.8        40.9
# 2019-03-23  43061       1.75       3.3       1.7         2.4        46.9
# 2019-03-24  38615       1.75       4.3       0.0         2.3        45.4
# 2019-03-25  25152       1.75       7.3       0.0         2.0        56.1
# 2019-03-26  28349       1.75      11.4       0.0         2.0        51.1
# 2019-03-27  27798       1.75      11.6       0.0         3.0        66.4
# 2019-03-28  28470       1.75       9.4       0.0         2.6        49.9
# 2019-03-29  34783       1.75       9.2       0.0         2.1        33.1
# 2019-03-30  42589       1.75       5.2       1.8         2.9        72.0
# 2019-03-31  38192       1.75       4.4       0.0         3.2        46.0
#
#             1시간 최다일사량(MJ/m2)  일 최심신적설(cm)  KOSPI지수  KOSDAQ지수  weekday_0  \
# 일자
# 2019-02-01              2.04          0.0  2203.46    716.92          0
# 2019-02-02              0.83          0.0  2203.46    716.92          0
# 2019-02-03              0.10          0.0  2203.46    716.92          0
# 2019-02-04              2.16          0.0  2203.46    716.92          1
# 2019-02-05              2.05          0.0  2203.46    716.92          0
# 2019-02-06              1.49          0.0  2203.42    728.79          0
# 2019-02-07              2.21          0.0  2203.42    728.79          0
# 2019-02-08              1.97          0.0  2177.05    728.74          0
# 2019-02-09              2.24          0.0  2177.05    728.74          0
# 2019-02-10              1.57          0.0  2180.73    733.47          0
# 2019-02-11              2.32          0.0  2180.73    733.47          1
# 2019-02-12              1.97          0.0  2190.47    730.58          0
# 2019-02-13              2.26          0.0  2201.48    739.91          0
# 2019-02-14              2.34          0.0  2225.85    742.27          0
# 2019-02-15              0.78          0.0  2196.09    738.66          0
# 2019-02-16              2.25          0.0  2196.09    738.66          0
# 2019-02-17              2.44          0.0  2210.89    745.33          0
# 2019-02-18              2.00          0.0  2210.89    745.33          1
# 2019-02-19              0.85          0.0  2205.63    748.05          0
# 2019-02-20              1.32          0.0  2229.76    750.69          0
# 2019-02-21              2.28          0.0  2228.66    747.33          0
# 2019-02-22              2.34          0.0  2230.50    743.38          0
# 2019-02-23              2.54          0.0  2230.50    743.38          0
# 2019-02-24              2.42          0.0  2232.56    750.40          0
# 2019-02-25              2.32          0.0  2232.56    750.40          1
# 2019-02-26              2.39          0.0  2226.60    747.09          0
# 2019-02-27              2.14          0.0  2234.79    752.16          0
# 2019-02-28              2.21          0.0  2195.44    731.25          0
# 2019-03-01              2.31          0.0  2195.44    731.25          0
# 2019-03-02              2.17          0.0  2195.44    731.25          0
# 2019-03-03              2.55          0.0  2190.66    748.07          0
# 2019-03-04              2.30          0.0  2190.66    748.07          1
# 2019-03-05              1.81          0.0  2179.23    747.95          0
# 2019-03-06              1.61          0.0  2175.60    746.70          0
# 2019-03-07              2.45          0.0  2165.79    736.83          0
# 2019-03-08              2.71          0.0  2137.44    735.97          0
# 2019-03-09              1.91          0.0  2137.44    735.97          0
# 2019-03-10              1.62          0.0  2137.44    735.97          0
# 2019-03-11              1.51          0.0  2138.10    739.09          1
# 2019-03-12              1.16          0.0  2157.18    754.76          0
# 2019-03-13              2.80          0.0  2148.41    754.89          0
# 2019-03-14              2.34          0.0  2155.68    755.42          0
# 2019-03-15              1.58          0.0  2176.11    748.36          0
# 2019-03-16              2.39          0.0  2176.11    748.36          0
# 2019-03-17              2.87          0.0  2179.49    753.13          0
# 2019-03-18              2.55          0.0  2179.49    753.13          1
# 2019-03-19              2.30          0.0  2177.62    748.91          0
# 2019-03-20              0.78          0.0  2177.10    749.76          0
# 2019-03-21              1.33          0.0  2184.88    743.52          0
# 2019-03-22              3.05          0.0  2186.95    743.97          0
# 2019-03-23              2.05          0.0  2186.95    743.97          0
# 2019-03-24              2.98          0.0  2144.86    727.21          0
# 2019-03-25              1.05          0.0  2144.86    727.21          1
# 2019-03-26              2.96          0.0  2148.80    736.81          0
# 2019-03-27              2.08          0.0  2145.62    728.45          0
# 2019-03-28              2.79          0.0  2128.10    719.72          0
# 2019-03-29              3.01          0.0  2140.67    729.31          0
# 2019-03-30              1.34          0.0  2140.67    729.31          0
# 2019-03-31              2.02          0.0  2140.67    729.31          0
#
#             weekday_1  weekday_2  weekday_3  weekday_4  weekday_5  weekday_6  \
# 일자
# 2019-02-01          0          0          0          1          0          0
# 2019-02-02          0          0          0          0          1          0
# 2019-02-03          0          0          0          0          0          1
# 2019-02-04          0          0          0          0          0          0
# 2019-02-05          1          0          0          0          0          0
# 2019-02-06          0          1          0          0          0          0
# 2019-02-07          0          0          1          0          0          0
# 2019-02-08          0          0          0          1          0          0
# 2019-02-09          0          0          0          0          1          0
# 2019-02-10          0          0          0          0          0          1
# 2019-02-11          0          0          0          0          0          0
# 2019-02-12          1          0          0          0          0          0
# 2019-02-13          0          1          0          0          0          0
# 2019-02-14          0          0          1          0          0          0
# 2019-02-15          0          0          0          1          0          0
# 2019-02-16          0          0          0          0          1          0
# 2019-02-17          0          0          0          0          0          1
# 2019-02-18          0          0          0          0          0          0
# 2019-02-19          1          0          0          0          0          0
# 2019-02-20          0          1          0          0          0          0
# 2019-02-21          0          0          1          0          0          0
# 2019-02-22          0          0          0          1          0          0
# 2019-02-23          0          0          0          0          1          0
# 2019-02-24          0          0          0          0          0          1
# 2019-02-25          0          0          0          0          0          0
# 2019-02-26          1          0          0          0          0          0
# 2019-02-27          0          1          0          0          0          0
# 2019-02-28          0          0          1          0          0          0
# 2019-03-01          0          0          0          1          0          0
# 2019-03-02          0          0          0          0          1          0
# 2019-03-03          0          0          0          0          0          1
# 2019-03-04          0          0          0          0          0          0
# 2019-03-05          1          0          0          0          0          0
# 2019-03-06          0          1          0          0          0          0
# 2019-03-07          0          0          1          0          0          0
# 2019-03-08          0          0          0          1          0          0
# 2019-03-09          0          0          0          0          1          0
# 2019-03-10          0          0          0          0          0          1
# 2019-03-11          0          0          0          0          0          0
# 2019-03-12          1          0          0          0          0          0
# 2019-03-13          0          1          0          0          0          0
# 2019-03-14          0          0          1          0          0          0
# 2019-03-15          0          0          0          1          0          0
# 2019-03-16          0          0          0          0          1          0
# 2019-03-17          0          0          0          0          0          1
# 2019-03-18          0          0          0          0          0          0
# 2019-03-19          1          0          0          0          0          0
# 2019-03-20          0          1          0          0          0          0
# 2019-03-21          0          0          1          0          0          0
# 2019-03-22          0          0          0          1          0          0
# 2019-03-23          0          0          0          0          1          0
# 2019-03-24          0          0          0          0          0          1
# 2019-03-25          0          0          0          0          0          0
# 2019-03-26          1          0          0          0          0          0
# 2019-03-27          0          1          0          0          0          0
# 2019-03-28          0          0          1          0          0          0
# 2019-03-29          0          0          0          1          0          0
# 2019-03-30          0          0          0          0          1          0
# 2019-03-31          0          0          0          0          0          1
#
#             prev_week_avg  holiday  myungjul
# 일자
# 2019-02-01   35375.857143        0         0
# 2019-02-02   34962.714286        0         0
# 2019-02-03   34179.857143        0         0
# 2019-02-04   33410.142857        1         0
# 2019-02-05   32239.000000        1         1
# 2019-02-06   29966.000000        1         0
# 2019-02-07   29675.142857        0         0
# 2019-02-08   28886.000000        0         0
# 2019-02-09   28224.857143        0         0
# 2019-02-10   28860.428571        0         0
# 2019-02-11   29830.428571        0         0
# 2019-02-12   31085.285714        0         0
# 2019-02-13   33542.857143        0         0
# 2019-02-14   34059.428571        0         0
# 2019-02-15   34822.857143        0         0
# 2019-02-16   36069.571429        0         0
# 2019-02-17   36338.285714        0         0
# 2019-02-18   36213.857143        0         0
# 2019-02-19   36095.428571        0         0
# 2019-02-20   36355.428571        0         0
# 2019-02-21   36360.857143        0         0
# 2019-02-22   36571.142857        0         0
# 2019-02-23   35766.714286        0         0
# 2019-02-24   35465.000000        0         0
# 2019-02-25   35438.714286        0         0
# 2019-02-26   35681.571429        0         0
# 2019-02-27   35531.285714        0         0
# 2019-02-28   35566.714286        0         0
# 2019-03-01   36033.714286        1         0
# 2019-03-02   36356.000000        0         0
# 2019-03-03   36017.428571        0         0
# 2019-03-04   35560.285714        0         0
# 2019-03-05   35400.428571        0         0
# 2019-03-06   34963.428571        0         0
# 2019-03-07   34383.428571        0         0
# 2019-03-08   33109.000000        0         0
# 2019-03-09   32448.714286        0         0
# 2019-03-10   32792.000000        0         0
# 2019-03-11   33091.571429        0         0
# 2019-03-12   32660.857143        0         0
# 2019-03-13   32681.857143        0         0
# 2019-03-14   32756.571429        0         0
# 2019-03-15   32826.571429        0         0
# 2019-03-16   33361.142857        0         0
# 2019-03-17   33480.000000        0         0
# 2019-03-18   33418.285714        0         0
# 2019-03-19   33274.714286        0         0
# 2019-03-20   32986.142857        0         0
# 2019-03-21   33331.142857        0         0
# 2019-03-22   33294.000000        0         0
# 2019-03-23   32886.428571        0         0
# 2019-03-24   32988.000000        0         0
# 2019-03-25   33020.285714        0         0
# 2019-03-26   33082.571429        0         0
# 2019-03-27   33385.714286        0         0
# 2019-03-28   32813.285714        0         0
# 2019-03-29   32626.285714        0         0
# 2019-03-30   32318.285714        0         0
# 2019-03-31   32250.857143        0         0

# %% [markdown]
# ## 3. Data Normalization / Standardization
#
#
# 데이터 프레임의 컬럼에 따라 value의 범위가 크게 차이나기에 특정 컬럼에 편향된 결과가 나올 수 있기에 이를 방지하기 위해 데이터 정규화를 수행했다.
#
# min_max 정규화와 Z_score 정규화 두 가지 방법을 사용해 정규화를 수행했다.
#
#
# ### Data split
#
# train set은 13~16년 data를, validation set은 17년 data를, test set은 18년 data를 사용했다.

# %%
train = data[:'2016-12-31']
valid = data['2017-01-01':'2017-12-31']
test = data['2018-01-01':'2018-12-31']

# normalize the validation/test set using min & max of the training set
def normalize_set(df_train, df_new):
    ret = pd.DataFrame(index=df_new.index, columns=df_new.columns)
    trainset_max = df_train.max()
    trainset_min = df_train.min()
    for col_name in df_train.columns :
        ret.loc[:,col_name] = (df_new[col_name] - trainset_min[col_name]) / (trainset_max[col_name] - trainset_min[col_name])
    return ret

# zscore the validation/test set using the mean & standard deviation of the training set
def zscore_set(df_train, df_new):
    ret = pd.DataFrame(index=df_new.index, columns=df_new.columns)
    trainset_mean = df_train.mean()
    trainset_std = df_train.std()
    for col_name in df_train.columns :
        ret.loc[:,col_name] = (df_new[col_name] - trainset_mean[col_name]) / trainset_std[col_name]
    return ret

# %%
train
# Out:
#              통화건수  한국은행 기준금리  평균기온(°C)  일강수량(mm)  평균 풍속(m/s)  평균 상대습도(%)  \
# 일자
# 2014-01-01  55628       2.50       4.0       0.0         3.7        51.3
# 2014-01-02  38344       2.50       1.5       0.0         2.0        35.4
# 2014-01-03  44865       2.50       2.3       0.0         2.5        54.4
# 2014-01-04  57280       2.50      -0.1       0.0         2.4        47.1
# 2014-01-05  56907       2.50      -0.8       0.0         1.9        48.4
# 2014-01-06  36267       2.50       0.8       0.0         1.6        50.4
# 2014-01-07  39305       2.50       3.0       0.0         1.7        56.0
# 2014-01-08  42840       2.50       0.5       0.0         3.3        56.6
# 2014-01-09  45344       2.50      -7.8       0.0         3.6        26.3
# 2014-01-10  51654       2.50      -4.7       0.0         2.0        48.6
# 2014-01-11  60706       2.50      -1.7       0.0         1.9        44.1
# 2014-01-12  64649       2.50      -2.4       0.0         3.4        43.5
# 2014-01-13  39219       2.50      -6.2       0.0         2.9        26.0
# 2014-01-14  41153       2.50      -4.3       0.0         2.2        33.8
# 2014-01-15  42854       2.50      -2.9       0.0         1.7        42.0
# 2014-01-16  43264       2.50       0.1       0.0         1.9        59.9
# 2014-01-17  49326       2.50      -0.1       0.0         1.6        55.9
# 2014-01-18  62632       2.50      -2.2       0.0         3.1        42.4
# 2014-01-19  60363       2.50      -2.6       0.0         1.9        44.8
# 2014-01-20  40782       2.50      -1.5       5.3         3.2        83.3
# 2014-01-21  41474       2.50      -5.5       0.7         2.4        62.6
# 2014-01-22  41330       2.50      -3.9       0.0         1.6        60.0
# 2014-01-23  42229       2.50      -0.8       0.0         2.1        66.0
# 2014-01-24  47292       2.50       3.0       0.0         2.6        64.0
# 2014-01-25  63192       2.50       4.2       3.0         2.4        74.4
# 2014-01-26  57806       2.50      -2.1       0.0         2.7        42.1
# 2014-01-27  35717       2.50       0.2       0.0         2.6        48.0
# 2014-01-28  39980       2.50       1.5       0.5         2.9        52.8
# 2014-01-29  45606       2.50       2.2       0.0         2.2        40.1
# 2014-01-30  28743       2.50       4.0       3.5         3.0        66.1
# ...           ...        ...       ...       ...         ...         ...
# 2016-12-02  53812       1.25       1.6       0.0         1.7        48.0
# 2016-12-03  62807       1.25       4.5       0.0         1.4        58.8
# 2016-12-04  58696       1.25       5.5       0.0         1.2        60.0
# 2016-12-05  40450       1.25       5.9       1.5         3.0        69.1
# 2016-12-06  43567       1.25      -1.1       0.0         2.5        38.5
# 2016-12-07  44739       1.25       1.7       0.0         2.3        58.3
# 2016-12-08  47740       1.25       2.1       3.0         1.7        70.0
# 2016-12-09  59396       1.25       1.4       3.0         2.8        65.8
# 2016-12-10  66134       1.25      -1.6       0.0         1.9        47.6
# 2016-12-11  63177       1.25      -1.1       0.0         1.2        42.6
# 2016-12-12  41337       1.25       2.3       0.0         1.9        37.9
# 2016-12-13  44273       1.25       3.4       0.0         2.0        53.6
# 2016-12-14  47284       1.25      -1.4       0.1         2.7        68.1
# 2016-12-15  49461       1.25      -5.0       0.0         3.0        42.0
# 2016-12-16  56938       1.25      -4.7       0.0         2.3        40.0
# 2016-12-17  62383       1.25       2.7       0.0         1.8        60.1
# 2016-12-18  57618       1.25       4.9       0.0         1.9        68.8
# 2016-12-19  39255       1.25       7.2       0.1         2.5        66.0
# 2016-12-20  42637       1.25       7.6       0.0         1.2        71.3
# 2016-12-21  47310       1.25       7.9      29.0         3.6        76.0
# 2016-12-22  49864       1.25       5.5      23.5         3.5        90.0
# 2016-12-23  56154       1.25      -2.5       0.1         3.4        71.0
# 2016-12-24  72126       1.25      -2.4       0.0         1.8        66.0
# 2016-12-25  64476       1.25       1.0       0.0         1.7        69.5
# 2016-12-26  41700       1.25       2.5       0.0         1.4        73.8
# 2016-12-27  45732       1.25      -2.3       0.5         3.5        54.6
# 2016-12-28  47252       1.25      -3.7       0.0         1.8        49.0
# 2016-12-29  51557       1.25      -4.2       0.3         2.9        53.0
# 2016-12-30  60057       1.25      -3.9       0.0         1.3        50.9
# 2016-12-31  66225       1.25       0.7       0.0         1.5        65.4
#
#             1시간 최다일사량(MJ/m2)  일 최심신적설(cm)  KOSPI지수  KOSDAQ지수  weekday_0  \
# 일자
# 2014-01-01              1.13          0.0  2011.34    499.99          0
# 2014-01-02              1.60          0.0  1967.19    496.28          0
# 2014-01-03              1.22          0.0  1946.14    499.33          0
# 2014-01-04              1.46          0.0  1946.14    499.33          0
# 2014-01-05              1.29          0.0  1946.14    499.33          0
# 2014-01-06              1.43          0.0  1953.28    500.62          1
# 2014-01-07              0.56          0.0  1959.44    504.86          0
# 2014-01-08              1.09          0.0  1958.96    509.78          0
# 2014-01-09              1.73          0.0  1946.11    511.60          0
# 2014-01-10              1.48          0.0  1938.54    510.19          0
# 2014-01-11              1.46          0.0  1938.54    510.19          0
# 2014-01-12              1.38          0.0  1938.54    510.19          0
# 2014-01-13              1.73          0.0  1948.92    512.92          1
# 2014-01-14              1.57          0.0  1946.07    512.27          0
# 2014-01-15              1.61          0.0  1953.28    515.97          0
# 2014-01-16              1.02          0.0  1957.32    517.83          0
# 2014-01-17              1.22          0.0  1944.48    518.10          0
# 2014-01-18              1.69          0.0  1944.48    518.10          0
# 2014-01-19              1.57          0.0  1944.48    518.10          0
# 2014-01-20              0.68          5.3  1953.78    519.99          1
# 2014-01-21              0.84          0.8  1963.89    520.99          0
# 2014-01-22              1.67          0.0  1970.42    523.07          0
# 2014-01-23              1.50          0.0  1947.59    522.72          0
# 2014-01-24              0.58          0.0  1940.56    520.31          0
# 2014-01-25              0.54          0.0  1940.56    520.31          0
# 2014-01-26              1.87          0.0  1940.56    520.31          0
# 2014-01-27              1.68          0.0  1910.34    507.51          1
# 2014-01-28              1.92          0.0  1916.93    509.29          0
# 2014-01-29              1.91          0.0  1941.15    515.20          0
# 2014-01-30              0.40          0.0  1941.15    515.20          0
# ...                      ...          ...      ...       ...        ...
# 2016-12-02              1.67          0.0  1970.61    586.73          0
# 2016-12-03              1.54          0.0  1970.61    586.73          0
# 2016-12-04              0.83          0.0  1970.61    586.73          0
# 2016-12-05              0.96          0.0  1963.36    575.12          1
# 2016-12-06              1.70          0.0  1989.86    581.35          0
# 2016-12-07              1.32          0.0  1991.89    578.52          0
# 2016-12-08              0.99          0.0  2031.07    584.62          0
# 2016-12-09              1.57          0.0  2024.69    594.35          0
# 2016-12-10              1.62          0.0  2024.69    594.35          0
# 2016-12-11              1.64          0.0  2024.69    594.35          0
# 2016-12-12              1.19          0.0  2027.24    603.08          1
# 2016-12-13              1.43          0.0  2035.98    611.09          0
# 2016-12-14              0.56          0.0  2036.87    612.47          0
# 2016-12-15              1.65          0.0  2036.65    620.61          0
# 2016-12-16              1.67          0.0  2042.24    622.08          0
# 2016-12-17              1.35          0.0  2042.24    622.08          0
# 2016-12-18              0.53          0.0  2042.24    622.08          0
# 2016-12-19              1.16          0.0  2038.39    622.77          1
# 2016-12-20              1.40          0.0  2041.94    617.99          0
# 2016-12-21              1.13          0.0  2037.96    618.63          0
# 2016-12-22              0.26          0.0  2035.73    615.93          0
# 2016-12-23              0.68          0.0  2035.90    619.75          0
# 2016-12-24              1.35          0.0  2035.90    619.75          0
# 2016-12-25              1.54          0.0  2035.90    619.75          0
# 2016-12-26              0.27          0.0  2037.75    615.16          1
# 2016-12-27              1.64          0.5  2042.17    618.38          0
# 2016-12-28              1.61          0.0  2024.49    627.27          0
# 2016-12-29              1.66          1.0  2026.46    631.44          0
# 2016-12-30              1.40          0.0  2026.46    631.44          0
# 2016-12-31              1.01          0.0  2026.46    631.44          0
#
#             weekday_1  weekday_2  weekday_3  weekday_4  weekday_5  weekday_6  \
# 일자
# 2014-01-01          0          1          0          0          0          0
# 2014-01-02          0          0          1          0          0          0
# 2014-01-03          0          0          0          1          0          0
# 2014-01-04          0          0          0          0          1          0
# 2014-01-05          0          0          0          0          0          1
# 2014-01-06          0          0          0          0          0          0
# 2014-01-07          1          0          0          0          0          0
# 2014-01-08          0          1          0          0          0          0
# 2014-01-09          0          0          1          0          0          0
# 2014-01-10          0          0          0          1          0          0
# 2014-01-11          0          0          0          0          1          0
# 2014-01-12          0          0          0          0          0          1
# 2014-01-13          0          0          0          0          0          0
# 2014-01-14          1          0          0          0          0          0
# 2014-01-15          0          1          0          0          0          0
# 2014-01-16          0          0          1          0          0          0
# 2014-01-17          0          0          0          1          0          0
# 2014-01-18          0          0          0          0          1          0
# 2014-01-19          0          0          0          0          0          1
# 2014-01-20          0          0          0          0          0          0
# 2014-01-21          1          0          0          0          0          0
# 2014-01-22          0          1          0          0          0          0
# 2014-01-23          0          0          1          0          0          0
# 2014-01-24          0          0          0          1          0          0
# 2014-01-25          0          0          0          0          1          0
# 2014-01-26          0          0          0          0          0          1
# 2014-01-27          0          0          0          0          0          0
# 2014-01-28          1          0          0          0          0          0
# 2014-01-29          0          1          0          0          0          0
# 2014-01-30          0          0          1          0          0          0
# ...               ...        ...        ...        ...        ...        ...
# 2016-12-02          0          0          0          1          0          0
# 2016-12-03          0          0          0          0          1          0
# 2016-12-04          0          0          0          0          0          1
# 2016-12-05          0          0          0          0          0          0
# 2016-12-06          1          0          0          0          0          0
# 2016-12-07          0          1          0          0          0          0
# 2016-12-08          0          0          1          0          0          0
# 2016-12-09          0          0          0          1          0          0
# 2016-12-10          0          0          0          0          1          0
# 2016-12-11          0          0          0          0          0          1
# 2016-12-12          0          0          0          0          0          0
# 2016-12-13          1          0          0          0          0          0
# 2016-12-14          0          1          0          0          0          0
# 2016-12-15          0          0          1          0          0          0
# 2016-12-16          0          0          0          1          0          0
# 2016-12-17          0          0          0          0          1          0
# 2016-12-18          0          0          0          0          0          1
# 2016-12-19          0          0          0          0          0          0
# 2016-12-20          1          0          0          0          0          0
# 2016-12-21          0          1          0          0          0          0
# 2016-12-22          0          0          1          0          0          0
# 2016-12-23          0          0          0          1          0          0
# 2016-12-24          0          0          0          0          1          0
# 2016-12-25          0          0          0          0          0          1
# 2016-12-26          0          0          0          0          0          0
# 2016-12-27          1          0          0          0          0          0
# 2016-12-28          0          1          0          0          0          0
# 2016-12-29          0          0          1          0          0          0
# 2016-12-30          0          0          0          1          0          0
# 2016-12-31          0          0          0          0          1          0
#
#             prev_week_avg  holiday  myungjul
# 일자
# 2014-01-01   57762.857143        1         0
# 2014-01-02   55670.285714        0         0
# 2014-01-03   55343.142857        0         0
# 2014-01-04   54632.571429        0         0
# 2014-01-05   53712.857143        0         0
# 2014-01-06   52712.285714        0         0
# 2014-01-07   51781.714286        0         0
# 2014-01-08   46942.285714        0         0
# 2014-01-09   45115.428571        0         0
# 2014-01-10   46115.428571        0         0
# 2014-01-11   47085.285714        0         0
# 2014-01-12   47574.714286        0         0
# 2014-01-13   48680.714286        0         0
# 2014-01-14   49102.428571        0         0
# 2014-01-15   49366.428571        0         0
# 2014-01-16   49368.428571        0         0
# 2014-01-17   49071.285714        0         0
# 2014-01-18   48738.714286        0         0
# 2014-01-19   49013.857143        0         0
# 2014-01-20   48401.571429        0         0
# 2014-01-21   48624.857143        0         0
# 2014-01-22   48670.714286        0         0
# 2014-01-23   48453.000000        0         0
# 2014-01-24   48305.142857        0         0
# 2014-01-25   48014.571429        0         0
# 2014-01-26   48094.571429        0         0
# 2014-01-27   47729.285714        0         0
# 2014-01-28   47005.714286        0         0
# 2014-01-29   46792.285714        0         0
# 2014-01-30   47403.142857        1         0
# ...                   ...      ...       ...
# 2016-12-02   51610.000000        0         0
# 2016-12-03   51348.428571        0         0
# 2016-12-04   50468.285714        0         0
# 2016-12-05   49959.857143        0         0
# 2016-12-06   49976.428571        0         0
# 2016-12-07   50011.428571        0         0
# 2016-12-08   49954.714286        0         0
# 2016-12-09   50258.714286        0         0
# 2016-12-10   51056.428571        0         0
# 2016-12-11   51531.714286        0         0
# 2016-12-12   52171.857143        0         0
# 2016-12-13   52298.571429        0         0
# 2016-12-14   52399.428571        0         0
# 2016-12-15   52763.000000        0         0
# 2016-12-16   53008.857143        0         0
# 2016-12-17   52657.714286        0         0
# 2016-12-18   52121.857143        0         0
# 2016-12-19   51327.714286        0         0
# 2016-12-20   51030.285714        0         0
# 2016-12-21   50796.571429        0         0
# 2016-12-22   50800.285714        0         0
# 2016-12-23   50857.857143        0         0
# 2016-12-24   50745.857143        0         0
# 2016-12-25   52137.714286        1         0
# 2016-12-26   53117.428571        0         0
# 2016-12-27   53466.714286        0         0
# 2016-12-28   53908.857143        0         0
# 2016-12-29   53900.571429        0         0
# 2016-12-30   54142.428571        0         0
# 2016-12-31   54700.000000        0         0
#
# [1096 rows x 20 columns]

# %%
zscore_set(train,train)
# Out:
#                 통화건수  한국은행 기준금리  평균기온(°C)  일강수량(mm)  평균 풍속(m/s)  평균 상대습도(%)  \
# 일자
# 2014-01-01  0.514949   1.572357 -0.910308 -0.277156    1.388865   -0.636462
# 2014-01-02 -0.669197   1.572357 -1.148896 -0.277156   -0.636599   -1.721658
# 2014-01-03 -0.222436   1.572357 -1.072548 -0.277156   -0.040875   -0.424883
# 2014-01-04  0.628129   1.572357 -1.301592 -0.277156   -0.160020   -0.923118
# 2014-01-05  0.602574   1.572357 -1.368397 -0.277156   -0.755744   -0.834391
# 2014-01-06 -0.811494   1.572357 -1.215701 -0.277156   -1.113179   -0.697888
# 2014-01-07 -0.603357   1.572357 -1.005743 -0.277156   -0.994034   -0.315681
# 2014-01-08 -0.361171   1.572357 -1.244331 -0.277156    0.912285   -0.274730
# 2014-01-09 -0.189619   1.572357 -2.036443 -0.277156    1.269720   -2.342745
# 2014-01-10  0.242686   1.572357 -1.740594 -0.277156   -0.636599   -0.820741
# 2014-01-11  0.862848   1.572357 -1.454289 -0.277156   -0.755744   -1.127872
# 2014-01-12  1.132987   1.572357 -1.521093 -0.277156    1.031430   -1.168822
# 2014-01-13 -0.609249   1.572357 -1.883747 -0.277156    0.435705   -2.363221
# 2014-01-14 -0.476749   1.572357 -1.702420 -0.277156   -0.398309   -1.830860
# 2014-01-15 -0.360212   1.572357 -1.568811 -0.277156   -0.994034   -1.271199
# 2014-01-16 -0.332122   1.572357 -1.282505 -0.277156   -0.755744   -0.049501
# 2014-01-17  0.083192   1.572357 -1.301592 -0.277156   -1.113179   -0.322506
# 2014-01-18  0.994800   1.572357 -1.502006 -0.277156    0.673995   -1.243899
# 2014-01-19  0.839349   1.572357 -1.540180 -0.277156   -0.755744   -1.080096
# 2014-01-20 -0.502167   1.572357 -1.435202  0.343797    0.793140    1.547580
# 2014-01-21 -0.454757   1.572357 -1.816942 -0.195143   -0.160020    0.134778
# 2014-01-22 -0.464623   1.572357 -1.664246 -0.277156   -1.113179   -0.042676
# 2014-01-23 -0.403031   1.572357 -1.368397 -0.277156   -0.517454    0.366832
# 2014-01-24 -0.056160   1.572357 -1.005743 -0.277156    0.078270    0.230330
# 2014-01-25  1.033166   1.572357 -0.891221  0.074327   -0.160020    0.940143
# 2014-01-26  0.664166   1.572357 -1.492463 -0.277156    0.197415   -1.264374
# 2014-01-27 -0.849175   1.572357 -1.272962 -0.277156    0.078270   -0.861692
# 2014-01-28 -0.557112   1.572357 -1.148896 -0.218576    0.435705   -0.534085
# 2014-01-29 -0.171669   1.572357 -1.082092 -0.277156   -0.398309   -1.400877
# 2014-01-30 -1.326971   1.572357 -0.910308  0.132907    0.554850    0.373657
# ...              ...        ...       ...       ...         ...         ...
# 2016-12-02  0.390533  -1.192005 -1.139353 -0.277156   -0.994034   -0.861692
# 2016-12-03  1.006790  -1.192005 -0.862591 -0.277156   -1.351469   -0.124577
# 2016-12-04  0.725141  -1.192005 -0.767156 -0.277156   -1.589759   -0.042676
# 2016-12-05 -0.524912  -1.192005 -0.728982 -0.101415    0.554850    0.578411
# 2016-12-06 -0.311363  -1.192005 -1.397027 -0.277156   -0.040875   -1.510079
# 2016-12-07 -0.231068  -1.192005 -1.129809 -0.277156   -0.279164   -0.158703
# 2016-12-08 -0.025467  -1.192005 -1.091635  0.074327   -0.994034    0.639837
# 2016-12-09  0.773098  -1.192005 -1.158440  0.074327    0.316560    0.353182
# 2016-12-10  1.234726  -1.192005 -1.444745 -0.277156   -0.755744   -0.888992
# 2016-12-11  1.032139  -1.192005 -1.397027 -0.277156   -1.589759   -1.230249
# 2016-12-12 -0.464143  -1.192005 -1.072548 -0.277156   -0.755744   -1.551030
# 2016-12-13 -0.262994  -1.192005 -0.967569 -0.277156   -0.636599   -0.479484
# 2016-12-14 -0.056708  -1.192005 -1.425658 -0.265440    0.197415    0.510160
# 2016-12-15  0.092441  -1.192005 -1.769224 -0.277156    0.554850   -1.271199
# 2016-12-16  0.604698  -1.192005 -1.740594 -0.277156   -0.279164   -1.407702
# 2016-12-17  0.977741  -1.192005 -1.034374 -0.277156   -0.874889   -0.035851
# 2016-12-18  0.651286  -1.192005 -0.824417 -0.277156   -0.755744    0.557936
# 2016-12-19 -0.606783  -1.192005 -0.604916 -0.265440   -0.040875    0.366832
# 2016-12-20 -0.375079  -1.192005 -0.566742 -0.277156   -1.589759    0.728564
# 2016-12-21 -0.054926  -1.192005 -0.538111  3.120510    1.269720    1.049345
# 2016-12-22  0.120051  -1.192005 -0.767156  2.476125    1.150575    2.004864
# 2016-12-23  0.550985  -1.192005 -1.530637 -0.265440    1.031430    0.708089
# 2016-12-24  1.645244  -1.192005 -1.521093 -0.277156   -0.874889    0.366832
# 2016-12-25  1.121135  -1.192005 -1.196614 -0.277156   -0.994034    0.605712
# 2016-12-26 -0.439273  -1.192005 -1.053461 -0.277156   -1.351469    0.899192
# 2016-12-27 -0.163037  -1.192005 -1.511550 -0.218576    1.150575   -0.411233
# 2016-12-28 -0.058900  -1.192005 -1.645159 -0.277156   -0.874889   -0.793440
# 2016-12-29  0.236040  -1.192005 -1.692876 -0.242008    0.435705   -0.520435
# 2016-12-30  0.818384  -1.192005 -1.664246 -0.277156   -1.470614   -0.663763
# 2016-12-31  1.240960  -1.192005 -1.225244 -0.277156   -1.232324    0.325881
#
#             1시간 최다일사량(MJ/m2)  일 최심신적설(cm)   KOSPI지수  KOSDAQ지수  weekday_0  \
# 일자
# 2014-01-01         -1.090079    -0.102772  0.316504 -1.863331  -0.407193
# 2014-01-02         -0.449475    -0.102772 -0.460344 -1.916493  -0.407193
# 2014-01-03         -0.967411    -0.102772 -0.830733 -1.872788  -0.407193
# 2014-01-04         -0.640293    -0.102772 -0.830733 -1.872788  -0.407193
# 2014-01-05         -0.872001    -0.102772 -0.830733 -1.872788  -0.407193
# 2014-01-06         -0.681183    -0.102772 -0.705100 -1.854303   2.453598
# 2014-01-07         -1.866983    -0.102772 -0.596711 -1.793546  -0.407193
# 2014-01-08         -1.144599    -0.102772 -0.605156 -1.723045  -0.407193
# 2014-01-09         -0.272287    -0.102772 -0.831261 -1.696965  -0.407193
# 2014-01-10         -0.613034    -0.102772 -0.964460 -1.717170  -0.407193
# 2014-01-11         -0.640293    -0.102772 -0.964460 -1.717170  -0.407193
# 2014-01-12         -0.749332    -0.102772 -0.964460 -1.717170  -0.407193
# 2014-01-13         -0.272287    -0.102772 -0.781817 -1.678050   2.453598
# 2014-01-14         -0.490365    -0.102772 -0.831964 -1.687364  -0.407193
# 2014-01-15         -0.435845    -0.102772 -0.705100 -1.634345  -0.407193
# 2014-01-16         -1.240008    -0.102772 -0.634013 -1.607692  -0.407193
# 2014-01-17         -0.967411    -0.102772 -0.859942 -1.603823  -0.407193
# 2014-01-18         -0.326806    -0.102772 -0.859942 -1.603823  -0.407193
# 2014-01-19         -0.490365    -0.102772 -0.859942 -1.603823  -0.407193
# 2014-01-20         -1.703424    12.988919 -0.696302 -1.576740   2.453598
# 2014-01-21         -1.485346     1.873332 -0.518410 -1.562411  -0.407193
# 2014-01-22         -0.354066    -0.102772 -0.403510 -1.532605  -0.407193
# 2014-01-23         -0.585774    -0.102772 -0.805219 -1.537621  -0.407193
# 2014-01-24         -1.839723    -0.102772 -0.928917 -1.572155  -0.407193
# 2014-01-25         -1.894242    -0.102772 -0.928917 -1.572155  -0.407193
# 2014-01-26         -0.081468    -0.102772 -0.928917 -1.572155  -0.407193
# 2014-01-27         -0.340436    -0.102772 -1.460657 -1.755573   2.453598
# 2014-01-28         -0.013319    -0.102772 -1.344702 -1.730066  -0.407193
# 2014-01-29         -0.026949    -0.102772 -0.918535 -1.645379  -0.407193
# 2014-01-30         -2.085061    -0.102772 -0.918535 -1.645379  -0.407193
# ...                      ...          ...       ...       ...        ...
# 2016-12-02         -0.354066    -0.102772 -0.400167 -0.620389  -0.407193
# 2016-12-03         -0.531254    -0.102772 -0.400167 -0.620389  -0.407193
# 2016-12-04         -1.498976    -0.102772 -0.400167 -0.620389  -0.407193
# 2016-12-05         -1.321787    -0.102772 -0.527736 -0.786754   2.453598
# 2016-12-06         -0.313176    -0.102772 -0.061451 -0.697481  -0.407193
# 2016-12-07         -0.831112    -0.102772 -0.025732 -0.738034  -0.407193
# 2016-12-08         -1.280898    -0.102772  0.663666 -0.650624  -0.407193
# 2016-12-09         -0.490365    -0.102772  0.551406 -0.511198  -0.407193
# 2016-12-10         -0.422215    -0.102772  0.551406 -0.511198  -0.407193
# 2016-12-11         -0.394956    -0.102772  0.551406 -0.511198  -0.407193
# 2016-12-12         -1.008300    -0.102772  0.596275 -0.386101   2.453598
# 2016-12-13         -0.681183    -0.102772  0.750061 -0.271322  -0.407193
# 2016-12-14         -1.866983    -0.102772  0.765721 -0.251547  -0.407193
# 2016-12-15         -0.381326    -0.102772  0.761850 -0.134905  -0.407193
# 2016-12-16         -0.354066    -0.102772  0.860210 -0.113840  -0.407193
# 2016-12-17         -0.790222    -0.102772  0.860210 -0.113840  -0.407193
# 2016-12-18         -1.907872    -0.102772  0.860210 -0.113840  -0.407193
# 2016-12-19         -1.049190    -0.102772  0.792466 -0.103953   2.453598
# 2016-12-20         -0.722073    -0.102772  0.854931 -0.172448  -0.407193
# 2016-12-21         -1.090079    -0.102772  0.784900 -0.163277  -0.407193
# 2016-12-22         -2.275879    -0.102772  0.745662 -0.201967  -0.407193
# 2016-12-23         -1.703424    -0.102772  0.748653 -0.147228  -0.407193
# 2016-12-24         -0.790222    -0.102772  0.748653 -0.147228  -0.407193
# 2016-12-25         -0.531254    -0.102772  0.748653 -0.147228  -0.407193
# 2016-12-26         -2.262249    -0.102772  0.781205 -0.213000   2.453598
# 2016-12-27         -0.394956     1.132293  0.858978 -0.166859  -0.407193
# 2016-12-28         -0.435845    -0.102772  0.547887 -0.039470  -0.407193
# 2016-12-29         -0.367696     2.367359  0.582550  0.020284  -0.407193
# 2016-12-30         -0.722073    -0.102772  0.582550  0.020284  -0.407193
# 2016-12-31         -1.253638    -0.102772  0.582550  0.020284  -0.407193
#
#             weekday_1  weekday_2  weekday_3  weekday_4  weekday_5  weekday_6  \
# 일자
# 2014-01-01  -0.407193   2.444470  -0.408713  -0.408713  -0.408713  -0.407193
# 2014-01-02  -0.407193  -0.408713   2.444470  -0.408713  -0.408713  -0.407193
# 2014-01-03  -0.407193  -0.408713  -0.408713   2.444470  -0.408713  -0.407193
# 2014-01-04  -0.407193  -0.408713  -0.408713  -0.408713   2.444470  -0.407193
# 2014-01-05  -0.407193  -0.408713  -0.408713  -0.408713  -0.408713   2.453598
# 2014-01-06  -0.407193  -0.408713  -0.408713  -0.408713  -0.408713  -0.407193
# 2014-01-07   2.453598  -0.408713  -0.408713  -0.408713  -0.408713  -0.407193
# 2014-01-08  -0.407193   2.444470  -0.408713  -0.408713  -0.408713  -0.407193
# 2014-01-09  -0.407193  -0.408713   2.444470  -0.408713  -0.408713  -0.407193
# 2014-01-10  -0.407193  -0.408713  -0.408713   2.444470  -0.408713  -0.407193
# 2014-01-11  -0.407193  -0.408713  -0.408713  -0.408713   2.444470  -0.407193
# 2014-01-12  -0.407193  -0.408713  -0.408713  -0.408713  -0.408713   2.453598
# 2014-01-13  -0.407193  -0.408713  -0.408713  -0.408713  -0.408713  -0.407193
# 2014-01-14   2.453598  -0.408713  -0.408713  -0.408713  -0.408713  -0.407193
# 2014-01-15  -0.407193   2.444470  -0.408713  -0.408713  -0.408713  -0.407193
# 2014-01-16  -0.407193  -0.408713   2.444470  -0.408713  -0.408713  -0.407193
# 2014-01-17  -0.407193  -0.408713  -0.408713   2.444470  -0.408713  -0.407193
# 2014-01-18  -0.407193  -0.408713  -0.408713  -0.408713   2.444470  -0.407193
# 2014-01-19  -0.407193  -0.408713  -0.408713  -0.408713  -0.408713   2.453598
# 2014-01-20  -0.407193  -0.408713  -0.408713  -0.408713  -0.408713  -0.407193
# 2014-01-21   2.453598  -0.408713  -0.408713  -0.408713  -0.408713  -0.407193
# 2014-01-22  -0.407193   2.444470  -0.408713  -0.408713  -0.408713  -0.407193
# 2014-01-23  -0.407193  -0.408713   2.444470  -0.408713  -0.408713  -0.407193
# 2014-01-24  -0.407193  -0.408713  -0.408713   2.444470  -0.408713  -0.407193
# 2014-01-25  -0.407193  -0.408713  -0.408713  -0.408713   2.444470  -0.407193
# 2014-01-26  -0.407193  -0.408713  -0.408713  -0.408713  -0.408713   2.453598
# 2014-01-27  -0.407193  -0.408713  -0.408713  -0.408713  -0.408713  -0.407193
# 2014-01-28   2.453598  -0.408713  -0.408713  -0.408713  -0.408713  -0.407193
# 2014-01-29  -0.407193   2.444470  -0.408713  -0.408713  -0.408713  -0.407193
# 2014-01-30  -0.407193  -0.408713   2.444470  -0.408713  -0.408713  -0.407193
# ...               ...        ...        ...        ...        ...        ...
# 2016-12-02  -0.407193  -0.408713  -0.408713   2.444470  -0.408713  -0.407193
# 2016-12-03  -0.407193  -0.408713  -0.408713  -0.408713   2.444470  -0.407193
# 2016-12-04  -0.407193  -0.408713  -0.408713  -0.408713  -0.408713   2.453598
# 2016-12-05  -0.407193  -0.408713  -0.408713  -0.408713  -0.408713  -0.407193
# 2016-12-06   2.453598  -0.408713  -0.408713  -0.408713  -0.408713  -0.407193
# 2016-12-07  -0.407193   2.444470  -0.408713  -0.408713  -0.408713  -0.407193
# 2016-12-08  -0.407193  -0.408713   2.444470  -0.408713  -0.408713  -0.407193
# 2016-12-09  -0.407193  -0.408713  -0.408713   2.444470  -0.408713  -0.407193
# 2016-12-10  -0.407193  -0.408713  -0.408713  -0.408713   2.444470  -0.407193
# 2016-12-11  -0.407193  -0.408713  -0.408713  -0.408713  -0.408713   2.453598
# 2016-12-12  -0.407193  -0.408713  -0.408713  -0.408713  -0.408713  -0.407193
# 2016-12-13   2.453598  -0.408713  -0.408713  -0.408713  -0.408713  -0.407193
# 2016-12-14  -0.407193   2.444470  -0.408713  -0.408713  -0.408713  -0.407193
# 2016-12-15  -0.407193  -0.408713   2.444470  -0.408713  -0.408713  -0.407193
# 2016-12-16  -0.407193  -0.408713  -0.408713   2.444470  -0.408713  -0.407193
# 2016-12-17  -0.407193  -0.408713  -0.408713  -0.408713   2.444470  -0.407193
# 2016-12-18  -0.407193  -0.408713  -0.408713  -0.408713  -0.408713   2.453598
# 2016-12-19  -0.407193  -0.408713  -0.408713  -0.408713  -0.408713  -0.407193
# 2016-12-20   2.453598  -0.408713  -0.408713  -0.408713  -0.408713  -0.407193
# 2016-12-21  -0.407193   2.444470  -0.408713  -0.408713  -0.408713  -0.407193
# 2016-12-22  -0.407193  -0.408713   2.444470  -0.408713  -0.408713  -0.407193
# 2016-12-23  -0.407193  -0.408713  -0.408713   2.444470  -0.408713  -0.407193
# 2016-12-24  -0.407193  -0.408713  -0.408713  -0.408713   2.444470  -0.407193
# 2016-12-25  -0.407193  -0.408713  -0.408713  -0.408713  -0.408713   2.453598
# 2016-12-26  -0.407193  -0.408713  -0.408713  -0.408713  -0.408713  -0.407193
# 2016-12-27   2.453598  -0.408713  -0.408713  -0.408713  -0.408713  -0.407193
# 2016-12-28  -0.407193   2.444470  -0.408713  -0.408713  -0.408713  -0.407193
# 2016-12-29  -0.407193  -0.408713   2.444470  -0.408713  -0.408713  -0.407193
# 2016-12-30  -0.407193  -0.408713  -0.408713   2.444470  -0.408713  -0.407193
# 2016-12-31  -0.407193  -0.408713  -0.408713  -0.408713   2.444470  -0.407193
#
#             prev_week_avg   holiday  myungjul
# 일자
# 2014-01-01       0.965818  4.722159 -0.074159
# 2014-01-02       0.756157 -0.211574 -0.074159
# 2014-01-03       0.723380 -0.211574 -0.074159
# 2014-01-04       0.652186 -0.211574 -0.074159
# 2014-01-05       0.560037 -0.211574 -0.074159
# 2014-01-06       0.459787 -0.211574 -0.074159
# 2014-01-07       0.366550 -0.211574 -0.074159
# 2014-01-08      -0.118326 -0.211574 -0.074159
# 2014-01-09      -0.301364 -0.211574 -0.074159
# 2014-01-10      -0.201172 -0.211574 -0.074159
# 2014-01-11      -0.103999 -0.211574 -0.074159
# 2014-01-12      -0.054962 -0.211574 -0.074159
# 2014-01-13       0.055852 -0.211574 -0.074159
# 2014-01-14       0.098105 -0.211574 -0.074159
# 2014-01-15       0.124556 -0.211574 -0.074159
# 2014-01-16       0.124756 -0.211574 -0.074159
# 2014-01-17       0.094984 -0.211574 -0.074159
# 2014-01-18       0.061663 -0.211574 -0.074159
# 2014-01-19       0.089230 -0.211574 -0.074159
# 2014-01-20       0.027884 -0.211574 -0.074159
# 2014-01-21       0.050255 -0.211574 -0.074159
# 2014-01-22       0.054850 -0.211574 -0.074159
# 2014-01-23       0.033036 -0.211574 -0.074159
# 2014-01-24       0.018222 -0.211574 -0.074159
# 2014-01-25      -0.010891 -0.211574 -0.074159
# 2014-01-26      -0.002876 -0.211574 -0.074159
# 2014-01-27      -0.039475 -0.211574 -0.074159
# 2014-01-28      -0.111971 -0.211574 -0.074159
# 2014-01-29      -0.133355 -0.211574 -0.074159
# 2014-01-30      -0.072152  4.722159 -0.074159
# ...                   ...       ...       ...
# 2016-12-02       0.349345 -0.211574 -0.074159
# 2016-12-03       0.323138 -0.211574 -0.074159
# 2016-12-04       0.234954 -0.211574 -0.074159
# 2016-12-05       0.184013 -0.211574 -0.074159
# 2016-12-06       0.185673 -0.211574 -0.074159
# 2016-12-07       0.189180 -0.211574 -0.074159
# 2016-12-08       0.183498 -0.211574 -0.074159
# 2016-12-09       0.213956 -0.211574 -0.074159
# 2016-12-10       0.293881 -0.211574 -0.074159
# 2016-12-11       0.341502 -0.211574 -0.074159
# 2016-12-12       0.405640 -0.211574 -0.074159
# 2016-12-13       0.418335 -0.211574 -0.074159
# 2016-12-14       0.428441 -0.211574 -0.074159
# 2016-12-15       0.464868 -0.211574 -0.074159
# 2016-12-16       0.489501 -0.211574 -0.074159
# 2016-12-17       0.454319 -0.211574 -0.074159
# 2016-12-18       0.400630 -0.211574 -0.074159
# 2016-12-19       0.321062 -0.211574 -0.074159
# 2016-12-20       0.291262 -0.211574 -0.074159
# 2016-12-21       0.267846 -0.211574 -0.074159
# 2016-12-22       0.268218 -0.211574 -0.074159
# 2016-12-23       0.273986 -0.211574 -0.074159
# 2016-12-24       0.262764 -0.211574 -0.074159
# 2016-12-25       0.402219  4.722159 -0.074159
# 2016-12-26       0.500379 -0.211574 -0.074159
# 2016-12-27       0.535375 -0.211574 -0.074159
# 2016-12-28       0.579675 -0.211574 -0.074159
# 2016-12-29       0.578844 -0.211574 -0.074159
# 2016-12-30       0.603077 -0.211574 -0.074159
# 2016-12-31       0.658941 -0.211574 -0.074159
#
# [1096 rows x 20 columns]

# %%
train_z = zscore_set(train, train)
valid_z = zscore_set(train, valid)
test_z = zscore_set(train, test)

# %%
train_n = normalize_set(train, train)
valid_n = normalize_set(train, valid)
test_n = normalize_set(train, test)

# %% [markdown]
# ## 4. Feature Extraction
#
# 앞서 Feature selection을 이용해 Feature의 수를 감소시켰다.
#
# 이번 단계에서는 Feature Extraction을 이용해 선정된 Feature 중에서 데이터를 설명하는데 큰 비중을 차지하고 있는 Feature를 찾아냈다.
#
# 이를 위해 PCA 분석을 실행했다.

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=3)
pca.fit(data)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=3, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
from sklearn.decomposition import PCA
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

def PCA_model(df,n):
    norm_df = normalize(df)     #normalizing
    pca = PCA(n_components=n) #n => the number of dimension for decomposing
    pca.fit(norm_df)
    df_pca = pd.DataFrame(pca.transform(norm_df),columns=df.columns, index=df.index)
    return df_pca

def normalize(data):
    normalized_data = ((data - data.mean()) / (data.max() - data.min()))
    return normalized_data

def correlation(data):
    corr = data.corr()
    sns.set(style="white")
    f, ax = plt.subplots(figsize=(11,9))
    cmap = sns.diverging_palette(220,10,as_cmap=True)
    sns.heatmap(corr, cmap=cmap, vmax=.3, center=0, square=True, linewidths=.5,
                cbar_kws={"shrink": .5})

# %%
PCA_model(data, 20)
# Out:
#                 통화건수  한국은행 기준금리  평균기온(°C)  일강수량(mm)  평균 풍속(m/s)  평균 상대습도(%)  \
# 일자
# 2014-01-01  0.771448  -0.492857 -0.050698 -0.412403    0.497085    0.576051
# 2014-01-02  0.720202  -0.427736 -0.018966  0.762480   -0.292392    0.396307
# 2014-01-03  0.842394  -0.096263  0.700201 -0.327569   -0.482012    0.041436
# 2014-01-04  0.970475   0.346245  0.217040  0.319756    0.544728   -0.246913
# 2014-01-05  0.926413   0.296258 -0.646841 -0.222965   -0.378805    0.079011
# 2014-01-06  0.668782  -0.618849 -0.160065 -0.046743   -0.020844   -0.521846
# 2014-01-07  0.699934  -0.500119 -0.113385 -0.044842   -0.004469   -0.403921
# 2014-01-08  0.760083  -0.483916 -0.068514 -0.395631    0.494447    0.584459
# 2014-01-09  0.753187  -0.435559 -0.009741  0.764541   -0.292257    0.399540
# 2014-01-10  0.822468  -0.081851  0.704707 -0.327326   -0.482423    0.043984
# 2014-01-11  0.943707   0.358744  0.217218  0.319439    0.544973   -0.246044
# 2014-01-12  0.950341   0.296197 -0.639593 -0.221585   -0.378087    0.080974
# 2014-01-13  0.684636  -0.628693 -0.144044 -0.044152   -0.020464   -0.516652
# 2014-01-14  0.702692  -0.505197 -0.091053 -0.042339   -0.005456   -0.397538
# 2014-01-15  0.721098  -0.470739 -0.060685 -0.395642    0.493429    0.587640
# 2014-01-16  0.712693  -0.414713 -0.035127  0.760659   -0.291901    0.392301
# 2014-01-17  0.801626  -0.076206  0.697843 -0.328462   -0.481830    0.041896
# 2014-01-18  0.961928   0.353102  0.224037  0.320551    0.545300   -0.244679
# 2014-01-19  0.901575   0.306919 -0.641451 -0.222724   -0.378536    0.080935
# 2014-01-20  0.707847  -0.620505 -0.178619 -0.047060   -0.020643   -0.529126
# 2014-01-21  0.708273  -0.502647 -0.110519 -0.044079   -0.005038   -0.403079
# 2014-01-22  0.705863  -0.466995 -0.066519 -0.396614    0.493289    0.585730
# 2014-01-23  0.713205  -0.416968 -0.030545  0.760922   -0.292566    0.392836
# 2014-01-24  0.824703  -0.087446  0.689160 -0.328688   -0.480751    0.039028
# 2014-01-25  0.957551   0.364191  0.195788  0.317262    0.546090   -0.252572
# 2014-01-26  0.909551   0.297008 -0.634542 -0.221776   -0.378468    0.082105
# 2014-01-27  0.696582  -0.632067 -0.153431 -0.045545   -0.021117   -0.520842
# 2014-01-28  0.724785  -0.511426 -0.091421 -0.042589   -0.005966   -0.399744
# 2014-01-29  0.724433  -0.467711 -0.054420 -0.395178    0.493709    0.588473
# 2014-01-30  0.728540  -0.476710 -0.029559  0.743612   -0.289086    0.379038
# ...              ...        ...       ...       ...         ...         ...
# 2019-03-02  0.056098   0.555236  0.232775  0.313611    0.565897   -0.233918
# 2019-03-03  0.004759   0.500744 -0.620473 -0.228120   -0.357335    0.093905
# 2019-03-04 -0.207183  -0.405179 -0.139457 -0.051970    0.000769   -0.508227
# 2019-03-05 -0.155914  -0.297067 -0.093530 -0.050144    0.015613   -0.391376
# 2019-03-06 -0.118485  -0.274355 -0.058256 -0.402149    0.514952    0.595708
# 2019-03-07 -0.123177  -0.223365 -0.006477  0.756610   -0.272242    0.407049
# 2019-03-08 -0.027375   0.112645  0.729957 -0.331999   -0.462352    0.057734
# 2019-03-09  0.087154   0.549029  0.231860  0.314056    0.565657   -0.234062
# 2019-03-10  0.044071   0.493546 -0.630119 -0.228284   -0.357178    0.092080
# 2019-03-11 -0.156447  -0.422639 -0.156080 -0.052842   -0.000098   -0.512811
# 2019-03-12 -0.127128  -0.310233 -0.096461 -0.049304    0.016243   -0.391188
# 2019-03-13 -0.095826  -0.288198 -0.033579 -0.399215    0.513890    0.601605
# 2019-03-14 -0.142805  -0.218077 -0.006454  0.756533   -0.271900    0.407857
# 2019-03-15 -0.040447   0.128452  0.702566 -0.334987   -0.461276    0.051063
# 2019-03-16  0.078711   0.555725  0.225990  0.312859    0.564999   -0.236829
# 2019-03-17  0.023154   0.498516 -0.621835 -0.228263   -0.358225    0.092729
# 2019-03-18 -0.224015  -0.407794 -0.136844 -0.051916    0.000186   -0.507341
# 2019-03-19 -0.189391  -0.291598 -0.083393 -0.049668    0.015527   -0.388497
# 2019-03-20 -0.123356  -0.261674 -0.080229 -0.404848    0.515054    0.589997
# 2019-03-21 -0.105627  -0.226303 -0.028893  0.754866   -0.271070    0.401049
# 2019-03-22 -0.041396   0.114059  0.736441 -0.331284   -0.461763    0.059518
# 2019-03-23  0.087918   0.548793  0.231170  0.314159    0.566024   -0.234470
# 2019-03-24  0.075632   0.482137 -0.616641 -0.226990   -0.359391    0.093806
# 2019-03-25 -0.142058  -0.428611 -0.159965 -0.052749    0.000432   -0.513545
# 2019-03-26 -0.155031  -0.298584 -0.073020 -0.048520    0.014425   -0.386979
# 2019-03-27 -0.071193  -0.289776 -0.053862 -0.401433    0.513927    0.594829
# 2019-03-28 -0.087368  -0.235743 -0.000861  0.757425   -0.273179    0.407342
# 2019-03-29 -0.031837   0.110741  0.736731 -0.331436   -0.462240    0.059038
# 2019-03-30  0.153480   0.533283  0.213722  0.313090    0.565389   -0.240388
# 2019-03-31  0.105425   0.470425 -0.627189 -0.227029   -0.358134    0.091351
#
#             1시간 최다일사량(MJ/m2)  일 최심신적설(cm)   KOSPI지수  KOSDAQ지수  weekday_0  \
# 일자
# 2014-01-01         -0.023549    -0.154356 -0.170662  0.178951   0.933568
# 2014-01-02         -0.010210    -0.130073 -0.278370  0.137905  -0.053177
# 2014-01-03         -0.036517    -0.199384 -0.042793  0.209821  -0.052060
# 2014-01-04         -0.040369    -0.183416 -0.190483  0.165894  -0.041660
# 2014-01-05         -0.015694    -0.198653 -0.192789  0.177621  -0.034479
# 2014-01-06         -0.623528    -0.155067 -0.149016  0.193388  -0.066291
# 2014-01-07          0.779105    -0.271690  0.031660  0.281956  -0.042382
# 2014-01-08         -0.026546    -0.217148 -0.067634  0.228346  -0.058144
# 2014-01-09         -0.006944    -0.249832 -0.490730  0.092995  -0.085868
# 2014-01-10         -0.035513    -0.256338 -0.199934  0.206320  -0.071393
# 2014-01-11         -0.040275    -0.208027 -0.241929  0.181050  -0.048593
# 2014-01-12         -0.013970    -0.210308 -0.283604  0.137824  -0.051030
# 2014-01-13         -0.620143    -0.222614 -0.487085  0.094813  -0.107627
# 2014-01-14          0.781224    -0.210614 -0.363503  0.137475  -0.091011
# 2014-01-15         -0.026754    -0.182274 -0.273160  0.176892  -0.074744
# 2014-01-16         -0.010985    -0.233716 -0.015164  0.275174  -0.026324
# 2014-01-17         -0.036835    -0.229626 -0.057785  0.255225  -0.052828
# 2014-01-18         -0.039321    -0.173444 -0.299059  0.142805  -0.058204
# 2014-01-19         -0.015359    -0.173481 -0.287771  0.165729  -0.047335
# 2014-01-20         -0.625125    -0.314098  0.198593  0.353871  -0.035584
# 2014-01-21          0.780194    -0.336450 -0.035869  0.300797  -0.054934
# 2014-01-22         -0.027766    -0.165224 -0.136183  0.249102  -0.061693
# 2014-01-23         -0.011442    -0.152103 -0.031822  0.250588  -0.033048
# 2014-01-24         -0.036603    -0.296992  0.107608  0.305760  -0.037105
# 2014-01-25         -0.041890    -0.265478  0.191871  0.331233  -0.000661
# 2014-01-26         -0.014953    -0.113149 -0.355373  0.118918  -0.059973
# 2014-01-27         -0.622788    -0.123957 -0.220976  0.127206  -0.083206
# 2014-01-28          0.779351    -0.048208 -0.189604  0.121513  -0.081354
# 2014-01-29         -0.027323    -0.056598 -0.285681  0.122179  -0.080594
# 2014-01-30         -0.008177    -0.280528  0.023654  0.281008   0.963974
# ...                      ...          ...       ...       ...        ...
# 2019-03-02         -0.043505    -0.021571 -0.337091  0.128315  -0.064500
# 2019-03-03         -0.018849     0.097661 -0.421473  0.076498  -0.072175
# 2019-03-04         -0.625933     0.056556 -0.263780  0.121395  -0.089771
# 2019-03-05          0.776092    -0.031497 -0.029609  0.212495  -0.064784
# 2019-03-06         -0.029971    -0.088378 -0.099911  0.195480  -0.065410
# 2019-03-07         -0.013317     0.039424 -0.244468  0.105479  -0.066468
# 2019-03-08         -0.038660     0.035315 -0.367910  0.047497  -0.102302
# 2019-03-09         -0.042753    -0.090921 -0.361845  0.091322  -0.069917
# 2019-03-10         -0.017922    -0.082912 -0.380005  0.078203  -0.064501
# 2019-03-11         -0.625828    -0.131454 -0.059304  0.191993  -0.069186
# 2019-03-12          0.778507    -0.230009 -0.101370  0.216366  -0.072625
# 2019-03-13         -0.028154     0.044110 -0.450027  0.023872  -0.114253
# 2019-03-14         -0.012797    -0.013925 -0.305493  0.113730  -0.071794
# 2019-03-15         -0.039753    -0.146649  0.059749  0.281633  -0.050012
# 2019-03-16         -0.044432    -0.001753 -0.119357  0.198675  -0.049323
# 2019-03-17         -0.019304     0.129262 -0.326926  0.100739  -0.068658
# 2019-03-18         -0.625984     0.060932 -0.343129  0.108865  -0.100176
# 2019-03-19          0.775791     0.070347 -0.202939  0.143984  -0.084198
# 2019-03-20         -0.031418    -0.193883  0.249843  0.352520  -0.023724
# 2019-03-21         -0.013434    -0.140481  0.116232  0.280581  -0.026408
# 2019-03-22         -0.037786     0.066393 -0.439433  0.056750  -0.112405
# 2019-03-23         -0.042169    -0.100684 -0.296849  0.154512  -0.065986
# 2019-03-24         -0.018278     0.103588 -0.436345  0.014859  -0.082988
# 2019-03-25         -0.625145    -0.212276 -0.040445  0.206017  -0.064967
# 2019-03-26          0.775551     0.206693 -0.273503  0.043393  -0.098247
# 2019-03-27         -0.030828     0.049481 -0.028569  0.133570  -0.067523
# 2019-03-28         -0.013668     0.129285 -0.270456  0.024239  -0.075325
# 2019-03-29         -0.038904     0.129727 -0.434931 -0.004658  -0.111725
# 2019-03-30         -0.043084    -0.190154  0.037345  0.225706  -0.033227
# 2019-03-31         -0.016910    -0.073878 -0.323461  0.074420  -0.069657
#
#             weekday_1  weekday_2  weekday_3  weekday_4  weekday_5  weekday_6  \
# 일자
# 2014-01-01   0.186501   0.118701  -0.066865  -0.124738  -0.128060  -0.038140
# 2014-01-02   0.121699  -0.215040  -0.108760  -0.096103   0.015184   0.034995
# 2014-01-03   0.061705  -0.091299  -0.087652  -0.043988   0.030326  -0.012745
# 2014-01-04   0.080195  -0.106898  -0.080709  -0.030030   0.017701   0.013675
# 2014-01-05   0.069943  -0.174834  -0.083239  -0.020742   0.008692   0.008775
# 2014-01-06   0.059592  -0.238668  -0.083013   0.013630   0.000110   0.018629
# 2014-01-07   0.029171  -0.231873  -0.110460  -0.098644   0.008932  -0.018430
# 2014-01-08   0.012584   0.061348  -0.106619  -0.052620  -0.000373  -0.021523
# 2014-01-09   0.066188   0.063407  -0.109835  -0.118490  -0.025247   0.044411
# 2014-01-10  -0.011537  -0.155544  -0.088016   0.038042  -0.021711   0.026805
# 2014-01-11   0.001983  -0.182001  -0.097980  -0.021774  -0.019373   0.032343
# 2014-01-12   0.060835   0.076154  -0.084218  -0.092283  -0.018015   0.002578
# 2014-01-13   0.094818  -0.059565  -0.090399  -0.109668  -0.017407   0.050942
# 2014-01-14   0.060290  -0.167374  -0.087717  -0.065816  -0.009559   0.043784
# 2014-01-15   0.037769  -0.228449  -0.071629   0.006696  -0.010979   0.042790
# 2014-01-16  -0.002043  -0.164752  -0.071119   0.012222  -0.006591  -0.007810
# 2014-01-17  -0.017462  -0.219365  -0.073489   0.018853  -0.005966   0.006834
# 2014-01-18   0.050004   0.018140  -0.068369  -0.045815  -0.008933   0.022332
# 2014-01-19   0.031047  -0.164207  -0.064282   0.003215  -0.015123   0.026648
# 2014-01-20  -0.030095   0.131478  -0.026765   0.159938  -0.004429  -0.070411
# 2014-01-21  -0.000962  -0.064346  -0.057307   0.056778   0.000608  -0.020378
# 2014-01-22  -0.007471  -0.189117  -0.043513   0.165752  -0.004392   0.020528
# 2014-01-23  -0.029288  -0.101508  -0.040055   0.127644  -0.004553  -0.005425
# 2014-01-24  -0.042978  -0.050580  -0.096057  -0.086022   0.008689  -0.044068
# 2014-01-25  -0.049241  -0.047992  -0.068197  -0.014825  -0.005998  -0.030351
# 2014-01-26   0.029768  -0.030863  -0.069194  -0.010265  -0.007373   0.023535
# 2014-01-27   0.000024  -0.068177  -0.080197  -0.007551  -0.008110   0.015142
# 2014-01-28  -0.006727  -0.004204  -0.072033   0.039491  -0.003210   0.012880
# 2014-01-29   0.028726  -0.151364  -0.085589  -0.038369  -0.022905   0.042731
# 2014-01-30  -0.125815   0.044463  -0.144565  -0.104647  -0.105672  -0.062422
# ...               ...        ...        ...        ...        ...        ...
# 2019-03-02  -0.140959  -0.204448  -0.050029  -0.051142   0.001747   0.029497
# 2019-03-03  -0.143103  -0.119573  -0.018637  -0.047554   0.005837   0.023325
# 2019-03-04  -0.111028  -0.057614   0.021271  -0.030568  -0.020415   0.010700
# 2019-03-05  -0.180601  -0.000259   0.035971   0.063511   0.002466  -0.033536
# 2019-03-06  -0.170099  -0.033782   0.007021  -0.050227  -0.001387  -0.020588
# 2019-03-07  -0.156385   0.009502   0.014346   0.050241  -0.011379   0.006620
# 2019-03-08  -0.172227  -0.063541   0.004328   0.013427  -0.017813   0.035612
# 2019-03-09  -0.197225  -0.191909  -0.048304  -0.143679  -0.016077   0.031720
# 2019-03-10  -0.184818  -0.222394  -0.073998  -0.256222  -0.014123   0.019645
# 2019-03-11  -0.211422  -0.050131   0.016892   0.004524  -0.016916  -0.026227
# 2019-03-12  -0.195902   0.083136   0.014540  -0.101492  -0.003054  -0.041381
# 2019-03-13  -0.146046   0.176120   0.043217  -0.005981  -0.007537   0.021951
# 2019-03-14  -0.184111  -0.049557   0.034983   0.013124  -0.020517   0.018679
# 2019-03-15  -0.230546  -0.039242   0.033545   0.116214  -0.016522  -0.012678
# 2019-03-16  -0.234789   0.014174   0.043479   0.225700   0.001339  -0.013738
# 2019-03-17  -0.199947   0.030326   0.030933   0.153486   0.003327   0.003565
# 2019-03-18  -0.159097  -0.132099   0.024000   0.035278  -0.023670   0.030235
# 2019-03-19  -0.187840  -0.126079   0.009047   0.033309  -0.010977   0.007383
# 2019-03-20  -0.251303  -0.076065   0.013957   0.007335  -0.017095   0.043389
# 2019-03-21  -0.212098   0.178034   0.014750   0.055849   0.000621  -0.051560
# 2019-03-22  -0.126649   0.110311   0.015799   0.071592  -0.011593   0.030654
# 2019-03-23  -0.172983   0.049578  -0.015572  -0.008368  -0.004809   0.012085
# 2019-03-24  -0.179645   0.051269  -0.005136   0.111462  -0.002249   0.021163
# 2019-03-25  -0.192516  -0.042764  -0.032717  -0.108697  -0.015652  -0.036300
# 2019-03-26  -0.173305  -0.022706   0.021300   0.087005  -0.014458   0.019032
# 2019-03-27  -0.198561   0.162431  -0.000251   0.038127   0.004965  -0.041585
# 2019-03-28  -0.175566   0.070469  -0.007568   0.054140  -0.013578   0.010332
# 2019-03-29  -0.157038  -0.046028  -0.024683  -0.027070  -0.018142   0.045443
# 2019-03-30  -0.248090   0.171935  -0.011057   0.039938   0.007027  -0.050724
# 2019-03-31  -0.187255   0.181687  -0.036371  -0.061901   0.006272  -0.021914
#
#             prev_week_avg   holiday      myungjul
# 일자
# 2014-01-01      -0.006844  0.028375  2.879405e-17
# 2014-01-02      -0.002733  0.091341  9.636610e-17
# 2014-01-03      -0.020381  0.094721  1.105257e-16
# 2014-01-04      -0.017608  0.064165 -1.594791e-16
# 2014-01-05      -0.015703  0.046093  7.740011e-17
# 2014-01-06      -0.014899  0.046734  2.654476e-16
# 2014-01-07      -0.007744  0.038263  9.971571e-17
# 2014-01-08      -0.010047 -0.008493  2.061765e-17
# 2014-01-09       0.004547 -0.030700  1.054580e-16
# 2014-01-10      -0.011690 -0.021790  1.184744e-16
# 2014-01-11      -0.007074 -0.015780 -9.746672e-17
# 2014-01-12      -0.004742 -0.049126  1.381986e-16
# 2014-01-13       0.001300  0.001819  2.689204e-16
# 2014-01-14       0.002149  0.007162  1.020236e-16
# 2014-01-15      -0.002175  0.005993  7.404065e-17
# 2014-01-16      -0.016285  0.008958  4.628336e-17
# 2014-01-17      -0.014887  0.015409  1.159283e-16
# 2014-01-18      -0.008983 -0.014543 -1.544021e-16
# 2014-01-19      -0.009282 -0.012423  8.144781e-17
# 2014-01-20       0.553986  0.055600  7.687612e-16
# 2014-01-21       0.066006  0.010433  1.024350e-16
# 2014-01-22      -0.021885  0.008996 -3.638236e-17
# 2014-01-23      -0.025845  0.008266 -8.439248e-18
# 2014-01-24      -0.018156  0.027144  1.165882e-16
# 2014-01-25      -0.022739 -0.023920 -1.537784e-16
# 2014-01-26      -0.009889  0.000535  8.223968e-17
# 2014-01-27      -0.011992  0.016537  2.142288e-16
# 2014-01-28      -0.009688 -0.000589 -7.192560e-18
# 2014-01-29       0.008930 -0.031029  7.625801e-17
# 2014-01-30      -0.031213  0.149500  9.962306e-18
# ...                   ...       ...           ...
# 2019-03-02      -0.002660  0.059088 -1.992468e-16
# 2019-03-03      -0.001086  0.061308  3.713175e-17
# 2019-03-04       0.001100 -0.021671  1.692000e-16
# 2019-03-05      -0.016003 -0.001686 -1.082181e-16
# 2019-03-06      -0.003211  0.002612 -5.233052e-17
# 2019-03-07      -0.007937 -0.001492 -7.958648e-17
# 2019-03-08       0.001006 -0.004455  1.865582e-17
# 2019-03-09       0.008814  0.015627 -1.403700e-16
# 2019-03-10       0.019144  0.025484  1.509324e-16
# 2019-03-11      -0.013874 -0.019241  1.158154e-16
# 2019-03-12      -0.006934 -0.018346 -5.034709e-17
# 2019-03-13       0.001143 -0.015247 -7.812075e-17
# 2019-03-14      -0.002165 -0.016239 -5.042954e-17
# 2019-03-15      -0.022640 -0.032240 -3.661205e-17
# 2019-03-16      -0.035492  0.011661 -3.632005e-16
# 2019-03-17      -0.022420  0.029004 -1.272160e-16
# 2019-03-18      -0.002128 -0.010542  1.710451e-16
# 2019-03-19      -0.000946 -0.004566 -5.087586e-17
# 2019-03-20      -0.009984 -0.020863 -2.287171e-17
# 2019-03-21      -0.027467 -0.007133 -1.064356e-16
# 2019-03-22      -0.007347 -0.008321 -3.701469e-17
# 2019-03-23      -0.012776  0.009549 -2.517693e-16
# 2019-03-24      -0.015592  0.024900 -7.128101e-17
# 2019-03-25      -0.006969 -0.013902  1.713879e-16
# 2019-03-26       0.000043 -0.020909 -1.062215e-16
# 2019-03-27      -0.012867 -0.001637 -1.342382e-16
# 2019-03-28      -0.004852 -0.005146 -7.823396e-17
# 2019-03-29       0.008982  0.001618  4.682721e-17
# 2019-03-30      -0.031400  0.008243 -3.067911e-16
# 2019-03-31      -0.012866  0.026711 -5.551115e-17
#
# [1916 rows x 20 columns]

# %%
correlation(data)

# %% [markdown]
# ## Base Model: Last Week Data

# %%
prev_week = prev_week.loc['2014-01-01':]
prediction = prev_week.loc['2018-01-01':'2018-12-31']

test_ev = explained_variance_score(data['통화건수'].loc['2018-01-01':'2018-12-31'], prediction)
print("testing set score: {:.3f}".format(test_ev))
# Out:
# testing set score: 0.263

# %% [markdown]
# ## Base Model: Last Week Average

# %%
prediction = data['prev_week_avg'].loc['2018-01-01':'2018-12-31']

test_ev = explained_variance_score(data['통화건수'].loc['2018-01-01':'2018-12-31'], prediction)
print("testing set score: {:.3f}".format(test_ev))
# Out:
# testing set score: 0.081

# %% [markdown]
# 첫 번째 Base Model은 지난 주 목표일의 통화건수가 이번 주 목표일의 데이터 동일하다고 판단한 모델이다.
#
# Score는 0.263 이다.
#
# 두 번째 Base Model은 지난 주 통화건수의 평균이 이번 주 목표일의 데이터와 동일하다고 판단하는 모델이다.
#
# Score는 0.081 이다.
#
# 이 후, 네 가지 모델로 나누어 학습을 진행하였다. 첫 번째 모델은 Linear Regression이다.

# %% [markdown]
# ## Model 1-1: Linear Regression
# 여기선 위에서 전처리가 완료된 Dataset을 이용하여 예측 모델을 학습시키고 그 결과를 도출해냈다.
#
# 먼저, 학습된 예측 모델의 성능의 실효성을 검증하기 위해 단순 데이터를 이용한 Base Model을 생성하였다.
#
# 이 때, 각 모델의 성능을 측정하기 위한 수치인 score는 Explained Variance Score를 이용하였다.
#
# Score는 0부터 1사이의 실수값을 가지며 1에 가까울수록 좋은 성능을 가진 모델이라고 할 수 있다.

# %%
x_train = train_z.drop(columns = ['통화건수'])
y_train = train_z['통화건수']

x_valid = valid_z.drop(columns = ['통화건수'])
y_valid = valid_z['통화건수']

model = LinearRegression()

reg = model.fit(x_train, y_train)

prediction = model.predict(x_valid)
prediction = pd.Series(data = prediction, index = y_valid.index)

# %% [markdown]
# 아래 목록은 위에서부터 선형 모델의 각 feature들의 가중치와 마지막으로 선형 모델의 절편값을 나타낸 것이다.

# %%
coef = pd.Series(data = model.coef_, index = x_train.columns)
print(coef.to_string(float_format = (lambda x: "{:.3f}".format(x))))
print(model.intercept_)
# Out:
# 한국은행 기준금리          -0.018
# 평균기온(°C)           -0.003
# 일강수량(mm)            0.065
# 평균 풍속(m/s)          0.023
# 평균 상대습도(%)          0.017
# 1시간 최다일사량(MJ/m2)   -0.008
# 일 최심신적설(cm)         0.016
# KOSPI지수             0.025
# KOSDAQ지수           -0.032
# weekday_0          -0.256
# weekday_1          -0.183
# weekday_2          -0.142
# weekday_3          -0.107
# weekday_4           0.071
# weekday_5           0.323
# weekday_6           0.293
# prev_week_avg       0.627
# holiday             0.058
# myungjul           -0.152
# 3.340020426736697e-15

# %% [markdown]
# 다음은 training set에 대한 모델의 score와 validation set에 대한 score를 각각 나타낸 것이다.

# %%
train_ev = explained_variance_score(y_train, model.predict(x_train))
print("training set score: {:.3f}".format(train_ev))
test_ev = explained_variance_score(y_valid, prediction)
print("validation set score: {:.3f}".format(test_ev))
# Out:
# training set score: 0.815
# validation set score: 0.685

# %% [markdown]
# 그리고 학습된 모델이 예측한 결과와 실제 결과를 위에서부터 차례대로 training set, validation set에 대해 그래프로 표현하였다.
#
# prediction 그래프가 학습한 모델이 예측한 결과를 나타낸 그래프이고 target 그래프는 실제 데이터의 그래프이다.

# %%
prediction_train = pd.Series(data = model.predict(x_train), index = y_train.index)
fig = plt.figure(figsize = (20,10))
ax = fig.add_subplot(1,1,1)
ax.plot(prediction_train, label='prediction')
ax.plot(y_train, label='target')
ax.set_title('Linear Regression with feature engineering - train')
ax.legend()

plt.show()
# Out:
# c:\program files\python\python36\lib\site-packages\pandas\plotting\_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
fig = plt.figure(figsize = (20,10))
ax = fig.add_subplot(1,1,1)
ax.plot(prediction, label='prediction')
ax.plot(y_valid, label='target')
ax.set_title('Linear Regression with feature engineering - validation')
ax.legend()

plt.show()

# %% [markdown]
# 마지막으로 실제 데이터와 예측 데이터 사이의 Mean Squared Error를 계산하여 출력하였다.

# %%
mse = mean_squared_error(y_valid, prediction)
mse
# Out:
# 0.13966196928606958

# %% [markdown]
# Linear Regression의 경우, 가장 기초적이고 단순하지만 강력하고 전통적인 예측 모델 중 하나이다.
#
# Training set score는 0.815, validation set score는 0.684로 준수한 성능을 내는 것을 알 수 있다.
#
# Validation set에서의 예측 그래프를 보면 통화건수의 경향과 하락폭 등을 잘 예측해낸 것을 볼 수 있다.
#
# 그러나 통화건수가 상승하는 기간의 경우, 상대적으로 높은 예측값을 낸 것을 알 수 있다.
#
# 통화건수가 상승하는 기간은 주말근처로, 주말에는 주로 전화주문을 통해서 자택에서 배달을 해서 식사를 하기 때문에
#
# 상대적으로 높은 통화건수를 기록하게 되는 것이다. Linear Regression의 경우, 이 weekday에 대한 민감도가
#
# 높다라는 것을 validation set 그래프를 통해 알 수 있다.
#
#
# 다음 모델은 Ridge Regression이다.

# %% [markdown]
# ## Model 1-2: Ridge Regression

# %% [markdown]
# 1. alpha값 조정

# %%
#alpha=5
from sklearn.linear_model import Ridge, Lasso
model_ridge = Ridge(alpha=5)

reg_ridge = model_ridge.fit(x_train, y_train)

prediction = model_ridge.predict(x_valid)
prediction = pd.Series(data = prediction, index = y_valid.index)

train_ev = explained_variance_score(y_train, model_ridge.predict(x_train))
print("training set score: {:.3f}".format(train_ev))
test_ev = explained_variance_score(y_valid, prediction)
print("validation set score: {:.3f}".format(test_ev))
# Out:
# training set score: 0.815
# validation set score: 0.687

# %%
#alpha=7

model_ridge = Ridge(alpha=7)

reg_ridge = model_ridge.fit(x_train, y_train)

prediction = model_ridge.predict(x_valid)
prediction = pd.Series(data = prediction, index = y_valid.index)

train_ev = explained_variance_score(y_train, model_ridge.predict(x_train))
print("training set score: {:.3f}".format(train_ev))
test_ev = explained_variance_score(y_valid, prediction)
print("validation set score: {:.3f}".format(test_ev))
# Out:
# training set score: 0.815
# validation set score: 0.688

# %%
#alpha=10

model_ridge = Ridge(alpha=10)

reg_ridge = model_ridge.fit(x_train, y_train)

prediction = model_ridge.predict(x_valid)
prediction = pd.Series(data = prediction, index = y_valid.index)

train_ev = explained_variance_score(y_train, model_ridge.predict(x_train))
print("training set score: {:.3f}".format(train_ev))
test_ev = explained_variance_score(y_valid, prediction)
print("validation set score: {:.3f}".format(test_ev))
# Out:
# training set score: 0.815
# validation set score: 0.689

# %%
#alpha=15

model_ridge = Ridge(alpha=15)

reg_ridge = model_ridge.fit(x_train, y_train)

prediction = model_ridge.predict(x_valid)
prediction = pd.Series(data = prediction, index = y_valid.index)

train_ev = explained_variance_score(y_train, model_ridge.predict(x_train))
print("training set score: {:.3f}".format(train_ev))
test_ev = explained_variance_score(y_valid, prediction)
print("validation set score: {:.3f}".format(test_ev))
# Out:
# training set score: 0.815
# validation set score: 0.691

# %%
#alpha=20

model_ridge = Ridge(alpha=20)

reg_ridge = model_ridge.fit(x_train, y_train)

prediction = model_ridge.predict(x_valid)
prediction = pd.Series(data = prediction, index = y_valid.index)

train_ev = explained_variance_score(y_train, model_ridge.predict(x_train))
print("training set score: {:.3f}".format(train_ev))
test_ev = explained_variance_score(y_valid, prediction)
print("validation set score: {:.3f}".format(test_ev))
# Out:
# training set score: 0.815
# validation set score: 0.693

# %%
#alpha=40

model_ridge = Ridge(alpha=40)

reg_ridge = model_ridge.fit(x_train, y_train)

prediction = model_ridge.predict(x_valid)
prediction = pd.Series(data = prediction, index = y_valid.index)

train_ev = explained_variance_score(y_train, model_ridge.predict(x_train))
print("training set score: {:.3f}".format(train_ev))
test_ev = explained_variance_score(y_valid, prediction)
print("validation set score: {:.3f}".format(test_ev))
# Out:
# training set score: 0.814
# validation set score: 0.700

# %%
coef = pd.Series(data = model_ridge.coef_, index = x_train.columns)
print(coef.to_string(float_format = (lambda x: "{:.3f}".format(x))))
print(model_ridge.intercept_)
# Out:
# 한국은행 기준금리          -0.018
# 평균기온(°C)           -0.002
# 일강수량(mm)            0.064
# 평균 풍속(m/s)          0.022
# 평균 상대습도(%)          0.017
# 1시간 최다일사량(MJ/m2)   -0.009
# 일 최심신적설(cm)         0.016
# KOSPI지수             0.025
# KOSDAQ지수           -0.035
# weekday_0          -0.254
# weekday_1          -0.182
# weekday_2          -0.140
# weekday_3          -0.106
# weekday_4           0.071
# weekday_5           0.320
# weekday_6           0.291
# prev_week_avg       0.621
# holiday             0.057
# myungjul           -0.150
# 3.2950470375135147e-15

# %% [markdown]
# Ridge Regression의 경우, training set score는 0.815 , validation set score는 0.689를 기록하였다.
#
# Linear Regression과 큰 차이를 보이지 않았다.
#
#
#
# 다음은 Lasso Regression이다.

# %% [markdown]
# ## Model 1-3. Lasso Regression

# %% [markdown]
# 1. alpha 값 조정

# %%
#alpha=0.01
model_lasso = Lasso(alpha=0.01, max_iter = 5000)

reg_lasso = model_lasso.fit(x_train, y_train)

prediction = model_lasso.predict(x_valid)
prediction = pd.Series(data = prediction, index = y_valid.index)

train_ev = explained_variance_score(y_train, model_lasso.predict(x_train))
print("training set score: {:.3f}".format(train_ev))
test_ev = explained_variance_score(y_valid, prediction)
print("validation set score: {:.3f}".format(test_ev))
# Out:
# training set score: 0.813
# validation set score: 0.712

# %%
#alpha=0.03
model_lasso = Lasso(alpha=0.03, max_iter = 5000)

reg_lasso = model_lasso.fit(x_train, y_train)

prediction = model_lasso.predict(x_valid)
prediction = pd.Series(data = prediction, index = y_valid.index)

train_ev = explained_variance_score(y_train, model_lasso.predict(x_train))
print("training set score: {:.3f}".format(train_ev))
test_ev = explained_variance_score(y_valid, prediction)
print("validation set score: {:.3f}".format(test_ev))
# Out:
# training set score: 0.804
# validation set score: 0.732

# %%
#alpha=0.05
model_lasso = Lasso(alpha=0.05, max_iter = 5000)

reg_lasso = model_lasso.fit(x_train, y_train)

prediction = model_lasso.predict(x_valid)
prediction = pd.Series(data = prediction, index = y_valid.index)

train_ev = explained_variance_score(y_train, model_lasso.predict(x_train))
print("training set score: {:.3f}".format(train_ev))
test_ev = explained_variance_score(y_valid, prediction)
print("validation set score: {:.3f}".format(test_ev))
# Out:
# training set score: 0.791
# validation set score: 0.735

# %%
#alpha=0.08
model_lasso = Lasso(alpha=0.08, max_iter = 5000)

reg_lasso = model_lasso.fit(x_train, y_train)

prediction = model_lasso.predict(x_valid)
prediction = pd.Series(data = prediction, index = y_valid.index)

train_ev = explained_variance_score(y_train, model_lasso.predict(x_train))
print("training set score: {:.3f}".format(train_ev))
test_ev = explained_variance_score(y_valid, prediction)
print("validation set score: {:.3f}".format(test_ev))
# Out:
# training set score: 0.761
# validation set score: 0.710

# %%
coef = pd.Series(data = model_lasso.coef_, index = x_train.columns)
print(coef.to_string(float_format = (lambda x: "{:.3f}".format(x))))
print(model_lasso.intercept_)
# Out:
# 한국은행 기준금리           0.000
# 평균기온(°C)            0.000
# 일강수량(mm)            0.028
# 평균 풍속(m/s)          0.000
# 평균 상대습도(%)          0.000
# 1시간 최다일사량(MJ/m2)   -0.000
# 일 최심신적설(cm)         0.000
# KOSPI지수             0.000
# KOSDAQ지수           -0.000
# weekday_0          -0.111
# weekday_1          -0.034
# weekday_2          -0.000
# weekday_3          -0.000
# weekday_4           0.134
# weekday_5           0.385
# weekday_6           0.354
# prev_week_avg       0.585
# holiday             0.000
# myungjul           -0.084
# 2.975233985698993e-15

# %% [markdown]
# Lasso Regression의 경우, training set score는 0.791 , validation set score는 0.735를 기록하였다.
#
# Linear와 Ridge Regression과 비교했을 때, validation set에 대한 score의 하락폭이 적다.
#
# 이는 낮은 bias와 적정한 variance를 가지는 모델임을 의미한다.
#
# 즉, Linear , Ridge Regression 보다 좋은 성능을 낸다는 것을 의미하는 것으로 해석할 수 있다.

# %% [markdown]
# ## Model2 : MLP

# %%
def mlp(df_train, df_valid, n, act, mi, lr):
    #train, test = train_test_split(df, test_size=ts)
        
    Mlp = MLPRegressor(activation = act, hidden_layer_sizes = (n, ),
                        learning_rate='constant',learning_rate_init=lr,
                        max_iter=mi)

    x_train = df_train.iloc[:,1:]
    y_train = df_train.iloc[:,0]

    x_valid = df_valid.iloc[:,1:]
    y_valid = df_valid.iloc[:,0]

    Mlp.fit(x_train,y_train)

    pred = Mlp.predict(x_valid)
    varSc = explained_variance_score(y_valid, pred) #1이 최고점수
    msle = mean_squared_log_error(y_valid, pred)

    print("Explained variance score = %f \nMean squared log error : %f"
          %(varSc, msle))

    return Mlp

# %% [markdown]
# Default hidden layer = 100, activation = 'relu', max_iter = 200, learning_rate = 0.001

# %% [markdown]
# 1. hidden layer size 조정

# %%
#default
print("normalized data")
mlp(train_n+1, valid_n+1, 100, 'relu', 200, 0.001)
print("z score data")
mlp(train_z+3, valid_z+3, 100, 'relu', 200, 0.001)
# Out:
# normalized data
# Explained variance score = 0.303631
# Mean squared log error : 0.001291
# z score data
# Explained variance score = 0.508076
# Mean squared log error : 0.026756
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=False)

# %%
#hideen layer size : 100 -> 500
print("normalized data")
mlp(train_n+1, valid_n+1, 500, 'relu', 200, 0.001)
print("z score data")
mlp(train_z+3, valid_z+3, 500, 'relu', 200, 0.001)
# Out:
# normalized data
# Explained variance score = 0.676713
# Mean squared log error : 0.000703
# z score data
# Explained variance score = 0.570482
# Mean squared log error : 0.017234
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(500,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=False)

# %%
#hideen layer size : 500 -> 1000
print("normalized data")
mlp(train_n+1, valid_n+1, 1000, 'relu', 200, 0.001)
print("z score data")
mlp(train_z+3, valid_z+3, 1000, 'relu', 200, 0.001)
# Out:
# normalized data
# Explained variance score = 0.617125
# Mean squared log error : 0.000609
# z score data
# Explained variance score = 0.567439
# Mean squared log error : 0.024779
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(1000,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=False)

# %%
#hideen layer size : 1000 -> 750
print("normalized data")
mlp(train_n+1, valid_n+1, 750, 'relu', 200, 0.001)
print("z score data")
mlp(train_z+3, valid_z+3, 750, 'relu', 200, 0.001)
# Out:
# normalized data
# Explained variance score = 0.681881
# Mean squared log error : 0.000399
# z score data
# Explained variance score = 0.513431
# Mean squared log error : 0.020062
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(750,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=False)

# %%
#hideen layer size : 750 -> 625
print("normalized data")
mlp(train_n+1, valid_n+1, 625, 'relu', 200, 0.001)
print("z score data")
mlp(train_z+3, valid_z+3, 625, 'relu', 200, 0.001)
# Out:
# normalized data
# Explained variance score = 0.655493
# Mean squared log error : 0.000438
# z score data
# Explained variance score = 0.630553
# Mean squared log error : 0.016214
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(625,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=False)

# %%
#hideen layer size : 625 -> 680
print("normalized data")
mlp(train_n+1, valid_n+1, 680, 'relu', 200, 0.001)
print("z score data")
mlp(train_z+3, valid_z+3, 680, 'relu', 200, 0.001)
# Out:
# normalized data
# Explained variance score = 0.520266
# Mean squared log error : 0.001630
# z score data
# Explained variance score = 0.622497
# Mean squared log error : 0.010022
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(680,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=False)

# %%
#hideen layer size : 680 -> 650
print("normalized data")
mlp(train_n+1, valid_n+1, 650, 'relu', 200, 0.001)
print("z score data")
mlp(train_z+3, valid_z+3, 650, 'relu', 200, 0.001)
# Out:
# normalized data
# Explained variance score = 0.672024
# Mean squared log error : 0.000454
# z score data
# Explained variance score = 0.566711
# Mean squared log error : 0.019848
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(650,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=False)

# %%
#hideen layer size : 650 -> 635
print("normalized data")
mlp(train_n+1, valid_n+1, 635, 'relu', 200, 0.001)
print("z score data")
mlp(train_z+3, valid_z+3, 635, 'relu', 200, 0.001)
# Out:
# normalized data
# Explained variance score = 0.633979
# Mean squared log error : 0.000859
# z score data
# Explained variance score = 0.571408
# Mean squared log error : 0.024851
# C:\Users\ML\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(635,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=False)

# %% [markdown]
# hidden layer size 650으로 결정, 제일 결과가 잘 나옴

# %% [markdown]
# 2. activation 함수 결정, default 'relu'

# %%
#activation = relu
print("normalized data")
mlp(train_n+1, valid_n+1, 650, 'relu', 200, 0.001)
print("z score data")
mlp(train_z+3, valid_z+3, 650, 'relu', 200, 0.001)
# Out:
# normalized data
# Explained variance score = 0.640399
# Mean squared log error : 0.000446
# z score data
# Explained variance score = 0.467046
# Mean squared log error : 0.014100
# C:\Users\ML\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(650,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=False)

# %%
#activation = identity
print("normalized data")
mlp(train_n+1, valid_n+1, 650, 'identity', 200, 0.001)
print("z score data")
mlp(train_z+3, valid_z+3, 650, 'identity', 200, 0.001)
# Out:
# normalized data
# Explained variance score = 0.533632
# Mean squared log error : 0.000901
# z score data
# Explained variance score = 0.683580
# Mean squared log error : 0.009741
# MLPRegressor(activation='identity', alpha=0.0001, batch_size='auto',
#        beta_1=0.9, beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(650,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=False)

# %%
#activation = logistic
print("normalized data")
mlp(train_n+1, valid_n+1, 650, 'logistic', 200, 0.001)
print("z score data")
mlp(train_z+3, valid_z+3, 650, 'logistic', 200, 0.001)
# Out:
# normalized data
# Explained variance score = 0.224314
# Mean squared log error : 0.001059
# z score data
# Explained variance score = 0.695877
# Mean squared log error : 0.009992
# MLPRegressor(activation='logistic', alpha=0.0001, batch_size='auto',
#        beta_1=0.9, beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(650,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=False)

# %%
#activation = tanh
print("normalized data")
mlp(train_n+1, valid_n+1, 650, 'tanh', 200, 0.001)
print("z score data")
mlp(train_z+3, valid_z+3, 650, 'tanh', 200, 0.001)
# Out:
# normalized data
# Explained variance score = 0.338708
# Mean squared log error : 0.001877
# z score data
# Explained variance score = 0.730011
# Mean squared log error : 0.006699
# MLPRegressor(activation='tanh', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(650,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=False)

# %% [markdown]
# activation tanh을 사용한 결과 70퍼를 넘어서 tanh으로 채택

# %% [markdown]
# 3. max_iter 결정, default 200

# %%
#default max_iter 200
print("normalized data")
mlp(train_n+1, valid_n+1, 650, 'tanh', 200, 0.001)
print("z score data")
mlp(train_z+3, valid_z+3, 650, 'tanh', 200, 0.001)
# Out:
# normalized data
# Explained variance score = 0.591798
# Mean squared log error : 0.000506
# z score data
# Explained variance score = 0.746311
# Mean squared log error : 0.006514
# MLPRegressor(activation='tanh', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(650,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=False)

# %%
#default max_iter 200 -> 300
print("normalized data")
mlp(train_n+1, valid_n+1, 650, 'tanh', 300, 0.001)
print("z score data")
mlp(train_z+3, valid_z+3, 650, 'tanh', 300, 0.001)
# Out:
# normalized data
# Explained variance score = 0.519462
# Mean squared log error : 0.000848
# z score data
# Explained variance score = 0.749440
# Mean squared log error : 0.008405
# MLPRegressor(activation='tanh', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(650,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=300, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=False)

# %%
#default max_iter 300 -> 400
print("normalized data")
mlp(train_n+1, valid_n+1, 650, 'tanh', 400, 0.001)
print("z score data")
mlp(train_z+3, valid_z+3, 650, 'tanh', 400, 0.001)
# Out:
# normalized data
# Explained variance score = 0.491094
# Mean squared log error : 0.000676
# z score data
# Explained variance score = 0.726368
# Mean squared log error : 0.007585
# MLPRegressor(activation='tanh', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(650,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=400, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=False)

# %%
#default max_iter 400 -> 350
print("normalized data")
mlp(train_n+1, valid_n+1, 650, 'tanh', 350, 0.001)
print("z score data")
mlp(train_z+3, valid_z+3, 650, 'tanh', 350, 0.001)
# Out:
# normalized data
# Explained variance score = 0.458330
# Mean squared log error : 0.001036
# z score data
# Explained variance score = 0.706008
# Mean squared log error : 0.008580
# MLPRegressor(activation='tanh', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(650,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=350, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=False)

# %%
#default max_iter 350 -> 325
print("normalized data")
mlp(train_n+1, valid_n+1, 650, 'tanh', 325, 0.001)
print("z score data")
mlp(train_z+3, valid_z+3, 650, 'tanh', 325, 0.001)
# Out:
# normalized data
# Explained variance score = 0.455316
# Mean squared log error : 0.001347
# z score data
# Explained variance score = 0.728085
# Mean squared log error : 0.006974
# MLPRegressor(activation='tanh', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(650,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=325, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=False)

# %%
#default max_iter 325 -> 313
print("normalized data")
mlp(train_n+1, valid_n+1, 650, 'tanh', 313, 0.001)
print("z score data")
mlp(train_z+3, valid_z+3, 650, 'tanh', 313, 0.001)
# Out:
# normalized data
# Explained variance score = 0.547441
# Mean squared log error : 0.001235
# z score data
# Explained variance score = 0.736852
# Mean squared log error : 0.007750
# MLPRegressor(activation='tanh', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(650,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=313, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=False)

# %% [markdown]
# max_iter는 300에서 가장 좋은 performance를 보임 300으로 결정함

# %% [markdown]
# 4. learning rate init 결정, default 0.001

# %%
#default learning rate 0.001
print("normalized data")
mlp(train_n+1, valid_n+1, 650, 'tanh', 300, 0.001)
print("z score data")
mlp(train_z+3, valid_z+3, 650, 'tanh', 300, 0.001)
# Out:
# normalized data
# Explained variance score = 0.579041
# Mean squared log error : 0.000562
# z score data
# Explained variance score = 0.741499
# Mean squared log error : 0.007242
# MLPRegressor(activation='tanh', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(650,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=300, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=False)

# %%
#default learning rate 0.001 -> 0.002
print("normalized data")
mlp(train_n+1, valid_n+1, 650, 'tanh', 300, 0.002)
print("z score data")
mlp(train_z+3, valid_z+3, 650, 'tanh', 300, 0.002)
# Out:
# normalized data
# Explained variance score = 0.613168
# Mean squared log error : 0.000511
# z score data
# Explained variance score = 0.757922
# Mean squared log error : 0.006476
# MLPRegressor(activation='tanh', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(650,), learning_rate='constant',
#        learning_rate_init=0.002, max_iter=300, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=False)

# %%
#default learning rate 0.002 -> 0.0005
print("normalized data")
mlp(train_n+1, valid_n+1, 650, 'tanh', 300, 0.0005)
print("z score data")
mlp(train_z+3, valid_z+3, 650, 'tanh', 300, 0.0005)
# Out:
# normalized data
# Explained variance score = 0.494768
# Mean squared log error : 0.000669
# z score data
# Explained variance score = 0.699038
# Mean squared log error : 0.007506
# MLPRegressor(activation='tanh', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(650,), learning_rate='constant',
#        learning_rate_init=0.0005, max_iter=300, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=False)

# %%
#default learning rate 0.0005 -> 0.00075
print("normalized data")
mlp(train_n+1, valid_n+1, 650, 'tanh', 300, 0.00075)
print("z score data")
mlp(train_z+3, valid_z+3, 650, 'tanh', 300, 0.00075)
# Out:
# normalized data
# Explained variance score = 0.376633
# Mean squared log error : 0.001669
# z score data
# Explained variance score = 0.736735
# Mean squared log error : 0.007545
# MLPRegressor(activation='tanh', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(650,), learning_rate='constant',
#        learning_rate_init=0.00075, max_iter=300, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=False)

# %%
#default learning rate 0.00075 -> 0.0015
print("normalized data")
mlp(train_n+1, valid_n+1, 650, 'tanh', 300, 0.0015)
print("z score data")
mlp(train_z+3, valid_z+3, 650, 'tanh', 300, 0.0015)
# Out:
# normalized data
# Explained variance score = 0.524928
# Mean squared log error : 0.000626
# z score data
# Explained variance score = 0.739291
# Mean squared log error : 0.006884
# MLPRegressor(activation='tanh', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(650,), learning_rate='constant',
#        learning_rate_init=0.0015, max_iter=300, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=False)

# %%
#default learning rate 0.0015 -> 0.00125
print("normalized data")
mlp(train_n+1, valid_n+1, 650, 'tanh', 300, 0.0015)
print("z score data")
mlp(train_z+3, valid_z+3, 650, 'tanh', 300, 0.0015)
# Out:
# normalized data
# Explained variance score = 0.585534
# Mean squared log error : 0.000691
# z score data
# Explained variance score = 0.745392
# Mean squared log error : 0.006746
# MLPRegressor(activation='tanh', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(650,), learning_rate='constant',
#        learning_rate_init=0.0015, max_iter=300, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=False)

# %% [markdown]
# performance가 크게 변화된 구간이 없어서 default인 0.001로 결정

# %% [markdown]
# 최종으로 수정한 점
# 1. hidden layer size : 100 -> 650
# 2. activation : relu -> tanh
# 3. max iteration : 200 -> 300
# 4. learning rate init : 0.001 default값 그대로

# %%
print("normalized data")
mlp_norm = mlp(train_n+1, valid_n+1, 650, 'tanh', 300, 0.001)
print("z score data")
mlp_z = mlp(train_z+3, valid_z+3, 650, 'tanh', 300, 0.001)
# Out:
# normalized data
# Explained variance score = 0.514466
# Mean squared log error : 0.000639
# z score data
# Explained variance score = 0.743739
# Mean squared log error : 0.007048

# %% [markdown]
# # Final model evaluation using the testing set

# %% [markdown]
# 여기서는 18년1월부터12월까지의 데이터인 test set을 이용해서 각 model의 성능을 측정했다.

# %%
x_test = test_z.drop(columns = ['통화건수'])
y_test = test_z['통화건수']

# %% [markdown]
# ## Linear Regression

# %%
prediction = model.predict(x_test)
prediction = pd.Series(data = prediction, index = y_test.index)
test_ev = explained_variance_score(y_test, prediction)
print("testing set score: {:.3f}".format(test_ev))
# Out:
# testing set score: 0.425

# %% [markdown]
# ## Ridge Regression

# %%
prediction = model_ridge.predict(x_test)
prediction = pd.Series(data = prediction, index = y_test.index)
test_ev = explained_variance_score(y_test, prediction)
print("testing set score: {:.3f}".format(test_ev))
# Out:
# testing set score: 0.433

# %% [markdown]
# ## LASSO

# %%
prediction = model_lasso.predict(x_test)
prediction = pd.Series(data = prediction, index = y_test.index)
test_ev = explained_variance_score(y_test, prediction)
print("testing set score: {:.3f}".format(test_ev))
# Out:
# testing set score: 0.553

# %% [markdown]
# ## MLP

# %%
print("normalized data")
mlp(train_n+1, test_n+1, 650, 'tanh', 300, 0.001)
print("z score data")
mlp(train_z+3, test_z+3, 650, 'tanh', 300, 0.001)
# Out:
# normalized data
# Explained variance score = 0.368624
# Mean squared log error : 0.001760
# z score data
# Explained variance score = 0.554277
# Mean squared log error : 0.010269
# MLPRegressor(activation='tanh', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(650,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=300, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=False)

# %%
print("normalized data")
mlp(train_n+1, test_n+1, 650, 'tanh', 300, 0.001)
print("z score data")
mlp(train_z+3, test_z+3, 650, 'tanh', 300, 0.001)
# Out:
# normalized data
# Explained variance score = 0.340685
# Mean squared log error : 0.000782
# z score data
# Explained variance score = 0.558942
# Mean squared log error : 0.010327
# MLPRegressor(activation='tanh', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(650,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=300, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=False)

# %% [markdown]
# 이를 통해 LASSO와 Multi-Layer Perceptron의 성능이 가장 좋다는 것을 알 수 있다.
# MLP 특성상 매 실행마다 결과값이 다르게 나와서 LASSO 보다 낮게 나올 때가 있고 높게 나올 때가 있다.
# 추후에 기회가 된다면 이 점을 보완해서 MLP로 이번 주제를 좀 더 완벽하게 해결할 수 있다고 생각한다.

# %% [markdown]
# # 7. Summary
#
# ### 결과 분석
#
#  이렇게 국내 증시 상황, 기상 정보, 요일의 변화, 최근의 통화건수 평균을 통해 음식점에 올 배달주문량을 예측하는
#
# 모델을 설계하고 학습시켜보았다. 예측 결과는 가장 성능이 좋은 LASSO와 MLP 모델의 경우 약 55~56% 정도의 정확도를 기록했다.
#
# 이를 통해 국내 증시 상황 등의 경제적 요소와 기상 정보가 배달 주문량에 영향을 미친다는 것을 알 수 있었다.
#
# 이는 곧 시장 경제에 대한 전체적인 분석으로 이어질 수 있는 중요한 정보라고 생각할 수 있다.
#
# 한 편, 외식업에서 소비자로 하여금 소비를 촉진하게 하는 것은 결국 소비자의 감정상태와 깊은 연관이 있음을
#
# 알 수 있는 결과이기도 하다.
#
# ### 문제점
#
# 이번 프로젝트에서 실현하고자 했던 결과는 자영업자, 특히 재고 관리에서 문제를 겪고 이로 인해 경영의 난이도가 높은
#
# 이른바 영세상인들에게 주문량에 대한 예측을 가능하게하여 효율적인 재고관리 도구를 제공하여 많은 수의 자영업자들이
#
# 최대한 경영에 난항을 겪지 않게끔 하는 것이었다. 그러나 현재 모델의 최고 성능은 55~56%대이며 이 역시 정확한
#
# 결과를 도출해내기 위해서 모델이 도출해낸 값을 denormalization하는 과정에서 실제 값과의 오류가 다소 증가할 것으로 보여진다.
# <br>
# <br>
#
# 만약 이 모델을 통해 영세상인들과 배달업체간의 제휴관계에서 영세상인들에게 더 나은 경영환경을 제공하고자 한다면
#
# 이 오류로 인해 발생하는 피해를 배달업체의 책임으로 돌려 보상을 받아내려는 의도로 악용될 수도 있을 것이다.
#
# 하지만 이 모델의 성능은 분명 개략적인 주문량의 예측을 하는 데에 도움을 줄 수 있을 것으로 보여지기 때문에
#
# 이 모델을 통해 재고 관리를 하는 데에 도움을 받는 상인이 늘어나게 되면 자연스레 지지를 받을 수 있을 것이다.
# <br>
# <br>
#
# 또한, 이 모델은 최근 통화건수의 평균을 feature로 사용하기 때문에 개업한지 얼마 되지 않은 가게의 경우
#
# 이 모델을 통해 주문량을 예측하는 것이 어려울 것으로 보여진다. 같은 이유로 이 프로젝트에서 해결하고자 했던 문제 중
#
# 지방의 상인들의 데이터 부족에 대한 해결 역시 모델도입 및 데이터수집 초창기에는 난항을 겪을 것으로 예상된다.
#
# ### 개선점
#
# 이 모델의 개선점은 다음과 같다.
#
# 1. 예측의 정확성
#
# 아주 기초적이지만 가장 중요한 요소이다. 높은 정확도를 지닌 예측모델은 그 만큼 큰 힘을 가지기 마련이다.
#
# 예측의 정확도를 높이기 위해선 배달주문과 연관된 새로운 feature의 발견이 해결책이 될 수 있을 것으로 보여진다.
#
# 국내에서 인기가 높은 스포츠의 경기 일정과 특정 음식에 대한 사람들의 검색량, 광고매체에서의 광고빈도 등이
#
# 새로운 feature로 쓰일 가능성이 높을 것으로 예상된다.
# <br>
# <br>
#
# 2. 메뉴별 예측
#
# 현재 모델에서 사용된 dataset은 메뉴를 구분하지 않고 단순히 배달주문 통화건수만을 기록해놓았다.
#
# 그러나 우리나라의 정서 상, 특정 상황에서 특정 메뉴의 판매량이 늘어나는 경우가 있다.
#
# 대표적으로 비가 오는 날의 부침개류가 있다. 이러한 특성들을 고려하여 메뉴별로 예측모델을
#
# 다르게 하는 것이 결과적으로 모델의 성능을 높일 수 있을 것으로 기대된다.
#
# 다만 그럴 경우, 음식메뉴별로 주문량을 새로 기록해야하기 때문에 이런 모델이 실현되는 것은
#
# 많은 시간이 걸릴 것으로 예상된다.
#
# ### 결론
#
# 이번 프로젝트에서 구현한 모델은 현재로서는 이대로 바로 현실에 적용하기에는 조금 무리일 수 있다.
#
# 아직 주문량의 변화에 미치는 수많은 변수들을 모두 고려하는 것도 아니고 정확도도 큰 경제적 이득을 기대하기에는 무리가 있기 때문이다.
#
# 하지만 자영업자들에게는 소비자의 입장에서 예상 매출에 대해 분석을 행하는 것이 중요한 만큼
#
# 상관관계가 있을 것으로 예상한 몇개의 feature들 그리고 10년도 안되는 기간동안의 데이터로도
#
# 어느정도 높은 예측률이 나온다는 점에서 시사하는 바가 크다고 생각한다.
#
# 이에 조금 더 feature들이 추가하고 모델이 보정하여 user-friendly한 형태로 자영업자들에게 배포한다면
#
# 예상 매출에 맞춰 계획을 짜는게 가능해져 낭비되는 자원을 줄이는데에 큰 도움이 될 것이라고 기대된다.
